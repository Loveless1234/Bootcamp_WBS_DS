# %% [markdown]
# ## Sending requests
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")

# %%
resp_json = response.json()

# %%
resp_json[:5]
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(resp_json).head()
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
requests.get("https://api.github.com/zen").text
# Out:
# 'Non-blocking is better than blocking.'

# %%
response = requests.get('https://api.github.com/events')

# %%
# get the .json from the response
github_response = response.json()

# %%
github_response
# Out:
# [{'id': '19010929495',
#   'type': 'WatchEvent',
#   'actor': {'id': 31913538,
#    'login': 'PENGsBIT',
#    'display_login': 'PENGsBIT',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PENGsBIT',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31913538?'},
#   'repo': {'id': 173063554,
#    'name': 'alibaba/RedisShake',
#    'url': 'https://api.github.com/repos/alibaba/RedisShake'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z',
#   'org': {'id': 1961952,
#    'login': 'alibaba',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/alibaba',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1961952?'}},
#  {'id': '19010929515',
#   'type': 'PushEvent',
#   'actor': {'id': 60386806,
#    'login': 'leanprover-community-bot',
#    'display_login': 'leanprover-community-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leanprover-community-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60386806?'},
#   'repo': {'id': 257845141,
#    'name': 'leanprover-community/archive',
#    'url': 'https://api.github.com/repos/leanprover-community/archive'},
#   'payload': {'push_id': 8451516563,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8cbcb921fbc09e53fc34e5bc51f2faeb45c2a3c5',
#    'before': '1240576f637f4a2a744f648cc809a7868921b41c',
#    'commits': [{'sha': '8cbcb921fbc09e53fc34e5bc51f2faeb45c2a3c5',
#      'author': {'email': 'zulip-archive-bot@users.noreply.github.com',
#       'name': 'Archive Bot'},
#      'message': 'Update archive.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/leanprover-community/archive/commits/8cbcb921fbc09e53fc34e5bc51f2faeb45c2a3c5'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z',
#   'org': {'id': 41703605,
#    'login': 'leanprover-community',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/leanprover-community',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41703605?'}},
#  {'id': '19010929500',
#   'type': 'PushEvent',
#   'actor': {'id': 64638744,
#    'login': 'ksidyagin',
#    'display_login': 'ksidyagin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ksidyagin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64638744?'},
#   'repo': {'id': 430368965,
#    'name': 'ksidyagin/volodarskmiriteam',
#    'url': 'https://api.github.com/repos/ksidyagin/volodarskmiriteam'},
#   'payload': {'push_id': 8451517298,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8d8dd21d5d49d630efbe21ba2bf923f42deab760',
#    'before': '645f1c33b202b0188cc006f40776d9a22703c138',
#    'commits': [{'sha': '8d8dd21d5d49d630efbe21ba2bf923f42deab760',
#      'author': {'email': '64638744+ksidyagin@users.noreply.github.com',
#       'name': 'ksidyagin'},
#      'message': 'upd',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ksidyagin/volodarskmiriteam/commits/8d8dd21d5d49d630efbe21ba2bf923f42deab760'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'},
#  {'id': '19010929493',
#   'type': 'CreateEvent',
#   'actor': {'id': 78209557,
#    'login': 'abby-cyber',
#    'display_login': 'abby-cyber',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abby-cyber',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78209557?'},
#   'repo': {'id': 401959197,
#    'name': 'abby-cyber/nebula-docs-cn',
#    'url': 'https://api.github.com/repos/abby-cyber/nebula-docs-cn'},
#   'payload': {'ref': 'add-whitespace-for-quick-start',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Repository for the Chinese documentations',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'},
#  {'id': '19010929483',
#   'type': 'CreateEvent',
#   'actor': {'id': 89975513,
#    'login': 'bhaskarboserackspace',
#    'display_login': 'bhaskarboserackspace',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bhaskarboserackspace',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89975513?'},
#   'repo': {'id': 233290577,
#    'name': 'rackerlabs/technical-blog',
#    'url': 'https://api.github.com/repos/rackerlabs/technical-blog'},
#   'payload': {'ref': 'oracle_docker',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': ':bulb:  Rackspace Expert Insights Technical Blog',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z',
#   'org': {'id': 84293,
#    'login': 'rackerlabs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rackerlabs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84293?'}},
#  {'id': '19010929456',
#   'type': 'PushEvent',
#   'actor': {'id': 60849980,
#    'login': 'jordans-bot',
#    'display_login': 'jordans-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jordans-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60849980?'},
#   'repo': {'id': 139190305,
#    'name': 'JTuwiner/bitcoinclock',
#    'url': 'https://api.github.com/repos/JTuwiner/bitcoinclock'},
#   'payload': {'push_id': 8451517275,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2a31fd3181b1e3519532a48babb0f2b7d4aeab5b',
#    'before': '84701f76a3d4c65b40d2025b17f916667b69b43b',
#    'commits': [{'sha': '2a31fd3181b1e3519532a48babb0f2b7d4aeab5b',
#      'author': {'email': '60849980+jordans-bot@users.noreply.github.com',
#       'name': 'jordans-bot'},
#      'message': 'Updated block height',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JTuwiner/bitcoinclock/commits/2a31fd3181b1e3519532a48babb0f2b7d4aeab5b'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'},
#  {'id': '19010929446',
#   'type': 'DeleteEvent',
#   'actor': {'id': 451373,
#    'login': 'xldenis',
#    'display_login': 'xldenis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xldenis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/451373?'},
#   'repo': {'id': 332798321,
#    'name': 'xldenis/creusot',
#    'url': 'https://api.github.com/repos/xldenis/creusot'},
#   'payload': {'ref': 'heapsort_jcf',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'},
#  {'id': '19010929462',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 259843170,
#    'name': 'maddijoyce/terraform-provider-aws',
#    'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws'},
#   'payload': {'action': 'closed',
#    'number': 532,
#    'pull_request': {'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls/532',
#     'id': 785821085,
#     'node_id': 'PR_kwDOD3zkYs4u1q2d',
#     'html_url': 'https://github.com/maddijoyce/terraform-provider-aws/pull/532',
#     'diff_url': 'https://github.com/maddijoyce/terraform-provider-aws/pull/532.diff',
#     'patch_url': 'https://github.com/maddijoyce/terraform-provider-aws/pull/532.patch',
#     'issue_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532',
#     'number': 532,
#     'state': 'closed',
#     'locked': False,
#     'title': 'build(deps): Bump github.com/aws/aws-sdk-go from 1.35.30 to 1.42.9',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [github.com/aws/aws-sdk-go](https://github.com/aws/aws-sdk-go) from 1.35.30 to 1.42.9.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/aws/aws-sdk-go/releases">github.com/aws/aws-sdk-go\'s releases</a>.</em></p>\n<blockquote>\n<h1>Release v1.42.9 (2021-11-19)</h1>\n<h3>Service Client Updates</h3>\n<ul>\n<li><code>service/application-insights</code>: Updates service API</li>\n<li><code>service/appstream</code>: Updates service API and documentation\n<ul>\n<li>Includes APIs for managing resources for Elastic fleets: applications, app blocks, and application-fleet associations.</li>\n</ul>\n</li>\n<li><code>service/batch</code>: Updates service documentation\n<ul>\n<li>Documentation updates for AWS Batch.</li>\n</ul>\n</li>\n<li><code>service/cloudformation</code>: Updates service API and documentation\n<ul>\n<li>The StackSets ManagedExecution feature will allow concurrency for non-conflicting StackSet operations and queuing the StackSet operations that conflict at a given time for later execution.</li>\n</ul>\n</li>\n<li><code>service/lambda</code>: Updates service API, documentation, and paginators\n<ul>\n<li>Add support for Lambda Function URLs. Customers can use Function URLs to create built-in HTTPS endpoints on their functions.</li>\n</ul>\n</li>\n<li><code>service/medialive</code>: Updates service API and documentation\n<ul>\n<li>This release adds support for specifying a SCTE-35 PID on input. MediaLive now supports SCTE-35 PID selection on inputs containing one or more active SCTE-35 PIDs.</li>\n</ul>\n</li>\n<li><code>service/redshift</code>: Updates service API and documentation\n<ul>\n<li>Added support of default IAM role for CreateCluster, RestoreFromClusterSnapshot and ModifyClusterIamRoles APIs</li>\n</ul>\n</li>\n<li><code>service/runtime.lex.v2</code>: Updates service API and documentation</li>\n</ul>\n<h1>Release v1.42.8 (2021-11-18)</h1>\n<h3>Service Client Updates</h3>\n<ul>\n<li><code>service/appconfig</code>: Updates service API, documentation, and examples</li>\n<li><code>service/auditmanager</code>: Updates service API, documentation, and paginators</li>\n<li><code>service/chime</code>: Updates service API and documentation\n<ul>\n<li>Adds new Transcribe API parameters to StartMeetingTranscription, including support for content identification and redaction (PII &amp; PHI), partial results stabilization, and custom language models.</li>\n</ul>\n</li>\n<li><code>service/chime-sdk-meetings</code>: Updates service API and documentation</li>\n<li><code>service/databrew</code>: Updates service API, documentation, and paginators</li>\n<li><code>service/forecast</code>: Updates service API and documentation</li>\n<li><code>service/ivs</code>: Updates service API, documentation, and paginators</li>\n<li><code>service/kafka</code>: Updates service API and documentation</li>\n<li><code>service/lambda</code>: Updates service API and documentation\n<ul>\n<li>Added support for CLIENT_CERTIFICATE_TLS_AUTH and SERVER_ROOT_CA_CERTIFICATE as SourceAccessType for MSK and Kafka event source mappings.</li>\n</ul>\n</li>\n<li><code>service/models.lex.v2</code>: Updates service API and documentation</li>\n<li><code>service/monitoring</code>: Updates service API and documentation\n<ul>\n<li>CloudWatch Anomaly Detection now supports anomaly detectors that use metric math as input.</li>\n</ul>\n</li>\n<li><code>service/redshift-data</code>: Updates service API and documentation</li>\n</ul>\n<h1>Release v1.42.7 (2021-11-17)</h1>\n<h3>Service Client Updates</h3>\n<ul>\n<li><code>service/amplifybackend</code>: Updates service API and documentation</li>\n<li><code>service/apigateway</code>: Updates service documentation\n<ul>\n<li>Documentation updates for Amazon API Gateway.</li>\n</ul>\n</li>\n<li><code>service/appconfigdata</code>: Adds new service</li>\n<li><code>service/devops-guru</code>: Updates service paginators</li>\n<li><code>service/drs</code>: Updates service  ...
#     'created_at': '2021-11-22T09:17:24Z',
#     'updated_at': '2021-11-23T09:13:55Z',
#     'closed_at': '2021-11-23T09:13:55Z',
#     'merged_at': None,
#     'merge_commit_sha': 'bcb509d6b9be999f459c3c5cc43f52f899439d31',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2513863541,
#       'node_id': 'MDU6TGFiZWwyNTEzODYzNTQx',
#       'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 2513863543,
#       'node_id': 'MDU6TGFiZWwyNTEzODYzNTQz',
#       'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/labels/go',
#       'name': 'go',
#       'color': '16e2e2',
#       'default': False,
#       'description': 'Pull requests that update Go code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls/532/commits',
#     'review_comments_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls/532/comments',
#     'review_comment_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532/comments',
#     'statuses_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/statuses/38111bf13ce489042e7a1b401002210ea3ba53a6',
#     'head': {'label': 'maddijoyce:dependabot/go_modules/github.com/aws/aws-sdk-go-1.42.9',
#      'ref': 'dependabot/go_modules/github.com/aws/aws-sdk-go-1.42.9',
#      'sha': '38111bf13ce489042e7a1b401002210ea3ba53a6',
#      'user': {'login': 'maddijoyce',
#       'id': 2224291,
#       'node_id': 'MDQ6VXNlcjIyMjQyOTE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2224291?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/maddijoyce',
#       'html_url': 'https://github.com/maddijoyce',
#       'followers_url': 'https://api.github.com/users/maddijoyce/followers',
#       'following_url': 'https://api.github.com/users/maddijoyce/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/maddijoyce/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/maddijoyce/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/maddijoyce/subscriptions',
#       'organizations_url': 'https://api.github.com/users/maddijoyce/orgs',
#       'repos_url': 'https://api.github.com/users/maddijoyce/repos',
#       'events_url': 'https://api.github.com/users/maddijoyce/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/maddijoyce/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 259843170,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNTk4NDMxNzA=',
#       'name': 'terraform-provider-aws',
#       'full_name': 'maddijoyce/terraform-provider-aws',
#       'private': False,
#       'owner': {'login': 'maddijoyce',
#        'id': 2224291,
#        'node_id': 'MDQ6VXNlcjIyMjQyOTE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/2224291?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/maddijoyce',
#        'html_url': 'https://github.com/maddijoyce',
#        'followers_url': 'https://api.github.com/users/maddijoyce/followers',
#        'following_url': 'https://api.github.com/users/maddijoyce/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/maddijoyce/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/maddijoyce/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/maddijoyce/subscriptions',
#        'organizations_url': 'https://api.github.com/users/maddijoyce/orgs',
#        'repos_url': 'https://api.github.com/users/maddijoyce/repos',
#        'events_url': 'https://api.github.com/users/maddijoyce/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/maddijoyce/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/maddijoyce/terraform-provider-aws',
#       'description': 'Terraform AWS provider',
#       'fork': True,
#       'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws',
#       'forks_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/forks',
#       'keys_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/teams',
#       'hooks_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/hooks',
#       'issue_events_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/events',
#       'assignees_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/tags',
#       'blobs_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/languages',
#       'stargazers_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/stargazers',
#       'contributors_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/contributors',
#       'subscribers_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/subscribers',
#       'subscription_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/subscription',
#       'commits_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/merges',
#       'archive_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/downloads',
#       'issues_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/deployments',
#       'created_at': '2020-04-29T06:27:39Z',
#       'updated_at': '2020-11-18T06:54:25Z',
#       'pushed_at': '2021-11-23T09:13:52Z',
#       'git_url': 'git://github.com/maddijoyce/terraform-provider-aws.git',
#       'ssh_url': 'git@github.com:maddijoyce/terraform-provider-aws.git',
#       'clone_url': 'https://github.com/maddijoyce/terraform-provider-aws.git',
#       'svn_url': 'https://github.com/maddijoyce/terraform-provider-aws',
#       'homepage': 'https://www.terraform.io/docs/providers/aws/',
#       'size': 200591,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 16,
#       'license': {'key': 'mpl-2.0',
#        'name': 'Mozilla Public License 2.0',
#        'spdx_id': 'MPL-2.0',
#        'url': 'https://api.github.com/licenses/mpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTE0'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 16,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'maddijoyce:master',
#      'ref': 'master',
#      'sha': 'a691855b10c07fa806a661c186747509007dc1a0',
#      'user': {'login': 'maddijoyce',
#       'id': 2224291,
#       'node_id': 'MDQ6VXNlcjIyMjQyOTE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2224291?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/maddijoyce',
#       'html_url': 'https://github.com/maddijoyce',
#       'followers_url': 'https://api.github.com/users/maddijoyce/followers',
#       'following_url': 'https://api.github.com/users/maddijoyce/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/maddijoyce/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/maddijoyce/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/maddijoyce/subscriptions',
#       'organizations_url': 'https://api.github.com/users/maddijoyce/orgs',
#       'repos_url': 'https://api.github.com/users/maddijoyce/repos',
#       'events_url': 'https://api.github.com/users/maddijoyce/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/maddijoyce/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 259843170,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNTk4NDMxNzA=',
#       'name': 'terraform-provider-aws',
#       'full_name': 'maddijoyce/terraform-provider-aws',
#       'private': False,
#       'owner': {'login': 'maddijoyce',
#        'id': 2224291,
#        'node_id': 'MDQ6VXNlcjIyMjQyOTE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/2224291?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/maddijoyce',
#        'html_url': 'https://github.com/maddijoyce',
#        'followers_url': 'https://api.github.com/users/maddijoyce/followers',
#        'following_url': 'https://api.github.com/users/maddijoyce/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/maddijoyce/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/maddijoyce/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/maddijoyce/subscriptions',
#        'organizations_url': 'https://api.github.com/users/maddijoyce/orgs',
#        'repos_url': 'https://api.github.com/users/maddijoyce/repos',
#        'events_url': 'https://api.github.com/users/maddijoyce/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/maddijoyce/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/maddijoyce/terraform-provider-aws',
#       'description': 'Terraform AWS provider',
#       'fork': True,
#       'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws',
#       'forks_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/forks',
#       'keys_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/teams',
#       'hooks_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/hooks',
#       'issue_events_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/events',
#       'assignees_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/tags',
#       'blobs_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/languages',
#       'stargazers_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/stargazers',
#       'contributors_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/contributors',
#       'subscribers_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/subscribers',
#       'subscription_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/subscription',
#       'commits_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/merges',
#       'archive_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/downloads',
#       'issues_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/deployments',
#       'created_at': '2020-04-29T06:27:39Z',
#       'updated_at': '2020-11-18T06:54:25Z',
#       'pushed_at': '2021-11-23T09:13:52Z',
#       'git_url': 'git://github.com/maddijoyce/terraform-provider-aws.git',
#       'ssh_url': 'git@github.com:maddijoyce/terraform-provider-aws.git',
#       'clone_url': 'https://github.com/maddijoyce/terraform-provider-aws.git',
#       'svn_url': 'https://github.com/maddijoyce/terraform-provider-aws',
#       'homepage': 'https://www.terraform.io/docs/providers/aws/',
#       'size': 200591,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 16,
#       'license': {'key': 'mpl-2.0',
#        'name': 'Mozilla Public License 2.0',
#        'spdx_id': 'MPL-2.0',
#        'url': 'https://api.github.com/licenses/mpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTE0'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 16,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls/532'},
#      'html': {'href': 'https://github.com/maddijoyce/terraform-provider-aws/pull/532'},
#      'issue': {'href': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532'},
#      'comments': {'href': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls/532/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls/532/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/statuses/38111bf13ce489042e7a1b401002210ea3ba53a6'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 11,
#     'deletions': 18,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'},
#  {'id': '19010929445',
#   'type': 'CreateEvent',
#   'actor': {'id': 94897694,
#    'login': 'SalaMark',
#    'display_login': 'SalaMark',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SalaMark',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94897694?'},
#   'repo': {'id': 431033153,
#    'name': 'SalaMark/Escort',
#    'url': 'https://api.github.com/repos/SalaMark/Escort'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'},
#  {'id': '19010929443',
#   'type': 'CreateEvent',
#   'actor': {'id': 52290251,
#    'login': 'botcopado',
#    'display_login': 'botcopado',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/botcopado',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52290251?'},
#   'repo': {'id': 431033070,
#    'name': 'botcopado/moeldv_BMJMNBOL',
#    'url': 'https://api.github.com/repos/botcopado/moeldv_BMJMNBOL'},
#   'payload': {'ref': 'feature/US-0113954',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'},
#  {'id': '19010929409',
#   'type': 'PushEvent',
#   'actor': {'id': 5738285,
#    'login': 'hhhaiai',
#    'display_login': 'hhhaiai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hhhaiai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5738285?'},
#   'repo': {'id': 423674834,
#    'name': 'hhhaiai/Git_result',
#    'url': 'https://api.github.com/repos/hhhaiai/Git_result'},
#   'payload': {'push_id': 8451517263,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2fcd3524495013fc052068128d3250f96b8cbea6',
#    'before': '5d88b1e6348b3c223da6894fa5bd1f974fc8fd03',
#    'commits': [{'sha': '2fcd3524495013fc052068128d3250f96b8cbea6',
#      'author': {'email': 'sanbo.xyz@gmail.com', 'name': 'hhhaiai'},
#      'message': '完善对比测试【1.3-planA】--- RKQ1.201112.002 test-keys',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hhhaiai/Git_result/commits/2fcd3524495013fc052068128d3250f96b8cbea6'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'},
#  {'id': '19010929415',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 112933199,
#    'name': 'ioootech/coco',
#    'url': 'https://api.github.com/repos/ioootech/coco'},
#   'payload': {'action': 'opened',
#    'number': 758,
#    'pull_request': {'url': 'https://api.github.com/repos/ioootech/coco/pulls/758',
#     'id': 786769701,
#     'node_id': 'PR_kwDOBrs5T84u5Scl',
#     'html_url': 'https://github.com/ioootech/coco/pull/758',
#     'diff_url': 'https://github.com/ioootech/coco/pull/758.diff',
#     'patch_url': 'https://github.com/ioootech/coco/pull/758.patch',
#     'issue_url': 'https://api.github.com/repos/ioootech/coco/issues/758',
#     'number': 758,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump bytebuddy.version from 1.12.1 to 1.12.2',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps `bytebuddy.version` from 1.12.1 to 1.12.2.\nUpdates `byte-buddy` from 1.12.1 to 1.12.2\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/raphw/byte-buddy/releases">byte-buddy\'s releases</a>.</em></p>\n<blockquote>\n<h2>Byte Buddy 1.12.2</h2>\n<ul>\n<li>Improve error message when class file version is not supported.</li>\n<li>Avoid duplication of fields to store auxiliary objects.</li>\n<li>Fix Gradle plugin to be skipped when input files are empty.</li>\n<li>Resolve dynamic bootstrap constant type correctly.</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/raphw/byte-buddy/blob/master/release-notes.md">byte-buddy\'s changelog</a>.</em></p>\n<blockquote>\n<h3>22. November 2021: version 1.12.2</h3>\n<ul>\n<li>Improve error message when class file version is not supported.</li>\n<li>Avoid duplication of fields to store auxiliary objects.</li>\n<li>Fix Gradle plugin to be skipped when input files are empty.</li>\n<li>Resolve dynamic bootstrap constant type correctly.</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/raphw/byte-buddy/commit/8743d1895f00867dc7da54f6959f86191a3c2d3f"><code>8743d18</code></a> [maven-release-plugin] prepare release byte-buddy-1.12.2</li>\n<li><a href="https://github.com/raphw/byte-buddy/commit/9d8aa8a73237ea89660304af5c06dbd3e1d25024"><code>9d8aa8a</code></a> [release] Release new version</li>\n<li><a href="https://github.com/raphw/byte-buddy/commit/df804c3bd56f7c1d1c1936b16e294ad6bafd2de4"><code>df804c3</code></a> Ignore test.</li>\n<li><a href="https://github.com/raphw/byte-buddy/commit/2ca57bebc88c0c018609442406fd9cf42625f6b7"><code>2ca57be</code></a> Add auxiliary field mechanism.</li>\n<li><a href="https://github.com/raphw/byte-buddy/commit/e0e87be1fef933cb815f7206cbfd0340581200e4"><code>e0e87be</code></a> Add auxiliary field mechanism.</li>\n<li><a href="https://github.com/raphw/byte-buddy/commit/5447bf34959a9f53a454951ad0fe4e0dd630ccaf"><code>5447bf3</code></a> Clean up field name generation.</li>\n<li><a href="https://github.com/raphw/byte-buddy/commit/74e0e7ab2c994417baaab63a737033144de6bfad"><code>74e0e7a</code></a> Resolve correct owner type for constant dynamic bootstrap.</li>\n<li><a href="https://github.com/raphw/byte-buddy/commit/b3b87aa2ecb929ee50406a4042473a3965966e1c"><code>b3b87aa</code></a> Add test that checks for bootstrap from a different type.</li>\n<li><a href="https://github.com/raphw/byte-buddy/commit/70fd86fb4dc07cb286afdab0ffc43f69d646119b"><code>70fd86f</code></a> Add link.</li>\n<li><a href="https://github.com/raphw/byte-buddy/commit/30f4fd827010fc4ec49d873efbfd408c95d90920"><code>30f4fd8</code></a> Add mention of GitHub Sponsors.</li>\n<li>Additional commits viewable in <a href="https://github.com/raphw/byte-buddy/compare/byte-buddy-1.12.1...byte-buddy-1.12.2">compare view</a></li>\n</ul>\n</details>\n<br />\n\nUpdates `byte-buddy-agent` from 1.12.1 to 1.12.2\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/raphw/byte-buddy/releases">byte-buddy-agent\'s releases</a>.</em></p>\n<blockquote>\n<h2>Byte Buddy 1.12.2</h2>\n<ul>\n<li>Improve error message when class file version is not supported.</li>\n<li>Avoid duplication of fields to store auxiliary objects.</li>\n<li>Fix Gradle plugin to be skipped when input files are empty.</li>\n<li>Resolve dynamic bootstrap constant type correctly.</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/raphw/byte-buddy/blob/master/release-notes.md">byte-buddy-agent\'s changelog</a>.</em></p>\n<blockquote>\n<h3>22. November 2021: version 1.12.2</h3>\n<ul>\n<li>Improve error message when class file version is not supported.</li>\n<li>Avoid duplication of fields to store auxiliary objects.</li>\n<li>Fix Gradle plug ...
#     'created_at': '2021-11-23T09:13:54Z',
#     'updated_at': '2021-11-23T09:13:54Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/ioootech/coco/pulls/758/commits',
#     'review_comments_url': 'https://api.github.com/repos/ioootech/coco/pulls/758/comments',
#     'review_comment_url': 'https://api.github.com/repos/ioootech/coco/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ioootech/coco/issues/758/comments',
#     'statuses_url': 'https://api.github.com/repos/ioootech/coco/statuses/21b68636fb6207b0714302f10477b0cd24ab8fc2',
#     'head': {'label': 'ioootech:dependabot/maven/develop/bytebuddy.version-1.12.2',
#      'ref': 'dependabot/maven/develop/bytebuddy.version-1.12.2',
#      'sha': '21b68636fb6207b0714302f10477b0cd24ab8fc2',
#      'user': {'login': 'ioootech',
#       'id': 37173086,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3MTczMDg2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/37173086?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ioootech',
#       'html_url': 'https://github.com/ioootech',
#       'followers_url': 'https://api.github.com/users/ioootech/followers',
#       'following_url': 'https://api.github.com/users/ioootech/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ioootech/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ioootech/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ioootech/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ioootech/orgs',
#       'repos_url': 'https://api.github.com/users/ioootech/repos',
#       'events_url': 'https://api.github.com/users/ioootech/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ioootech/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 112933199,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTI5MzMxOTk=',
#       'name': 'coco',
#       'full_name': 'ioootech/coco',
#       'private': False,
#       'owner': {'login': 'ioootech',
#        'id': 37173086,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3MTczMDg2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/37173086?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ioootech',
#        'html_url': 'https://github.com/ioootech',
#        'followers_url': 'https://api.github.com/users/ioootech/followers',
#        'following_url': 'https://api.github.com/users/ioootech/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ioootech/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ioootech/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ioootech/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ioootech/orgs',
#        'repos_url': 'https://api.github.com/users/ioootech/repos',
#        'events_url': 'https://api.github.com/users/ioootech/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ioootech/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ioootech/coco',
#       'description': 'iooo boot project',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ioootech/coco',
#       'forks_url': 'https://api.github.com/repos/ioootech/coco/forks',
#       'keys_url': 'https://api.github.com/repos/ioootech/coco/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ioootech/coco/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ioootech/coco/teams',
#       'hooks_url': 'https://api.github.com/repos/ioootech/coco/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ioootech/coco/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ioootech/coco/events',
#       'assignees_url': 'https://api.github.com/repos/ioootech/coco/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ioootech/coco/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ioootech/coco/tags',
#       'blobs_url': 'https://api.github.com/repos/ioootech/coco/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ioootech/coco/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ioootech/coco/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ioootech/coco/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ioootech/coco/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ioootech/coco/languages',
#       'stargazers_url': 'https://api.github.com/repos/ioootech/coco/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ioootech/coco/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ioootech/coco/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ioootech/coco/subscription',
#       'commits_url': 'https://api.github.com/repos/ioootech/coco/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ioootech/coco/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ioootech/coco/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ioootech/coco/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ioootech/coco/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ioootech/coco/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ioootech/coco/merges',
#       'archive_url': 'https://api.github.com/repos/ioootech/coco/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ioootech/coco/downloads',
#       'issues_url': 'https://api.github.com/repos/ioootech/coco/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ioootech/coco/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ioootech/coco/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ioootech/coco/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ioootech/coco/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ioootech/coco/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ioootech/coco/deployments',
#       'created_at': '2017-12-03T14:08:34Z',
#       'updated_at': '2021-11-22T09:50:58Z',
#       'pushed_at': '2021-11-23T09:13:55Z',
#       'git_url': 'git://github.com/ioootech/coco.git',
#       'ssh_url': 'git@github.com:ioootech/coco.git',
#       'clone_url': 'https://github.com/ioootech/coco.git',
#       'svn_url': 'https://github.com/ioootech/coco',
#       'homepage': '',
#       'size': 6459,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 5,
#       'watchers': 2,
#       'default_branch': 'develop'}},
#     'base': {'label': 'ioootech:develop',
#      'ref': 'develop',
#      'sha': '0ff245afe4aacfe74dee86efa98abe327190d47b',
#      'user': {'login': 'ioootech',
#       'id': 37173086,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3MTczMDg2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/37173086?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ioootech',
#       'html_url': 'https://github.com/ioootech',
#       'followers_url': 'https://api.github.com/users/ioootech/followers',
#       'following_url': 'https://api.github.com/users/ioootech/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ioootech/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ioootech/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ioootech/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ioootech/orgs',
#       'repos_url': 'https://api.github.com/users/ioootech/repos',
# ...
#       'id': 50111866,
#       'node_id': 'RA_kwDOAnkkcc4C_KV6',
#       'name': 'sha256sums.txt',
#       'label': '',
#       'uploader': {'login': 'prombot',
#        'id': 18470668,
#        'node_id': 'MDQ6VXNlcjE4NDcwNjY4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/18470668?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/prombot',
#        'html_url': 'https://github.com/prombot',
#        'followers_url': 'https://api.github.com/users/prombot/followers',
#        'following_url': 'https://api.github.com/users/prombot/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/prombot/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/prombot/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/prombot/subscriptions',
#        'organizations_url': 'https://api.github.com/users/prombot/orgs',
#        'repos_url': 'https://api.github.com/users/prombot/repos',
#        'events_url': 'https://api.github.com/users/prombot/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/prombot/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'content_type': 'text/plain; charset=utf-8',
#       'state': 'uploaded',
#       'size': 3805,
#       'download_count': 0,
#       'created_at': '2021-11-23T09:09:52Z',
#       'updated_at': '2021-11-23T09:09:52Z',
#       'browser_download_url': 'https://github.com/prometheus-community/bind_exporter/releases/download/v0.5.0/sha256sums.txt'}],
#     'tarball_url': 'https://api.github.com/repos/prometheus-community/bind_exporter/tarball/v0.5.0',
#     'zipball_url': 'https://api.github.com/repos/prometheus-community/bind_exporter/zipball/v0.5.0',
#     'body': '* [FEATURE] Add support for RCODE metrics. #113\r\n* [BUGFIX] handle non integer values for zone serial. #97\r\n',
#     'short_description_html': '<ul>\n<li>[FEATURE] Add support for RCODE metrics. <a class="issue-link js-issue-link" data-error-text="Failed to load title" data-id="952859382" data-permission-text="Title is private" data-url="https://github.com/prometheus-community/bind_exporter/issues/113" data-hovercard-type="pull_request" data-hovercard-url="/prometheus-community/bind_exporter/pull/113/hovercard" href="https://github.com/prometheus-community/bind_exporter/pull/113">#113</a>\n</li>\n<li>[BUGFIX] handle non integer values for zone serial. <a class="issue-link js-issue-link" data-error-text="Failed to load title" data-id="824942857" data-permission-text="Title is private" data-url="https://github.com/prometheus-community/bind_exporter/issues/97" data-hovercard-type="pull_request" data-hovercard-url="/prometheus-community/bind_exporter/pull/97/hovercard" href="https://github.com/prometheus-community/bind_exporter/pull/97">#97</a>\n</li>\n</ul>',
#     'is_short_description_html_truncated': False}},
#   'public': True,
#   'created_at': '2021-11-23T09:13:54Z',
#   'org': {'id': 42581734,
#    'login': 'prometheus-community',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/prometheus-community',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42581734?'}},
#  {'id': '19010929337',
#   'type': 'CreateEvent',
#   'actor': {'id': 57990514,
#    'login': 'premdevapp',
#    'display_login': 'premdevapp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/premdevapp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57990514?'},
#   'repo': {'id': 431032709,
#    'name': 'premdevapp/github_actions_ci_cd',
#    'url': 'https://api.github.com/repos/premdevapp/github_actions_ci_cd'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'},
#  {'id': '19010929297',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 286992169,
#    'name': 'PennyDreadfulMTG/gatherling',
#    'url': 'https://api.github.com/repos/PennyDreadfulMTG/gatherling'},
#   'payload': {'ref': 'dependabot/composer/symfony/http-client-contracts-2.5.0',
#    'ref_type': 'branch',
#    'master_branch': 'dev',
#    'description': 'Magic: The Gathering tournament runner and tracker for Player Run Events',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z',
#   'org': {'id': 22494209,
#    'login': 'PennyDreadfulMTG',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PennyDreadfulMTG',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22494209?'}},
#  {'id': '19010929287',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 259843170,
#    'name': 'maddijoyce/terraform-provider-aws',
#    'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532',
#     'repository_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws',
#     'labels_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532/comments',
#     'events_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532/events',
#     'html_url': 'https://github.com/maddijoyce/terraform-provider-aws/pull/532',
#     'id': 1059891247,
#     'node_id': 'PR_kwDOD3zkYs4u1q2d',
#     'number': 532,
#     'title': 'build(deps): Bump github.com/aws/aws-sdk-go from 1.35.30 to 1.42.9',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 2513863541,
#       'node_id': 'MDU6TGFiZWwyNTEzODYzNTQx',
#       'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 2513863543,
#       'node_id': 'MDU6TGFiZWwyNTEzODYzNTQz',
#       'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/labels/go',
#       'name': 'go',
#       'color': '16e2e2',
#       'default': False,
#       'description': 'Pull requests that update Go code'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2021-11-22T09:17:24Z',
#     'updated_at': '2021-11-23T09:13:54Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/pulls/532',
#      'html_url': 'https://github.com/maddijoyce/terraform-provider-aws/pull/532',
#      'diff_url': 'https://github.com/maddijoyce/terraform-provider-aws/pull/532.diff',
#      'patch_url': 'https://github.com/maddijoyce/terraform-provider-aws/pull/532.patch',
#      'merged_at': None},
#     'body': 'Bumps [github.com/aws/aws-sdk-go](https://github.com/aws/aws-sdk-go) from 1.35.30 to 1.42.9.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/aws/aws-sdk-go/releases">github.com/aws/aws-sdk-go\'s releases</a>.</em></p>\n<blockquote>\n<h1>Release v1.42.9 (2021-11-19)</h1>\n<h3>Service Client Updates</h3>\n<ul>\n<li><code>service/application-insights</code>: Updates service API</li>\n<li><code>service/appstream</code>: Updates service API and documentation\n<ul>\n<li>Includes APIs for managing resources for Elastic fleets: applications, app blocks, and application-fleet associations.</li>\n</ul>\n</li>\n<li><code>service/batch</code>: Updates service documentation\n<ul>\n<li>Documentation updates for AWS Batch.</li>\n</ul>\n</li>\n<li><code>service/cloudformation</code>: Updates service API and documentation\n<ul>\n<li>The StackSets ManagedExecution feature will allow concurrency for non-conflicting StackSet operations and queuing the StackSet operations that conflict at a given time for later execution.</li>\n</ul>\n</li>\n<li><code>service/lambda</code>: Updates service API, documentation, and paginators\n<ul>\n<li>Add support for Lambda Function URLs. Customers can use Function URLs to create built-in HTTPS endpoints on their functions.</li>\n</ul>\n</li>\n<li><code>service/medialive</code>: Updates service API and documentation\n<ul>\n<li>This release adds support for specifying a SCTE-35 PID on input. MediaLive now supports SCTE-35 PID selection on inputs containing one or more active SCTE-35 PIDs.</li>\n</ul>\n</li>\n<li><code>service/redshift</code>: Updates service API and documentation\n<ul>\n<li>Added support of default IAM role for CreateCluster, RestoreFromClusterSnapshot and ModifyClusterIamRoles APIs</li>\n</ul>\n</li>\n<li><code>service/runtime.lex.v2</code>: Updates service API and documentation</li>\n</ul>\n<h1>Release v1.42.8 (2021-11-18)</h1>\n<h3>Service Client Updates</h3>\n<ul>\n<li><code>service/appconfig</code>: Updates service API, documentation, and examples</li>\n<li><code>service/auditmanager</code>: Updates service API, documentation, and paginators</li>\n<li><code>service/chime</code>: Updates service API and documentation\n<ul>\n<li>Adds new Transcribe API parameters to StartMeetingTranscription, including support for content identification and redaction (PII &amp; PHI), partial results stabilization, and custom language models.</li>\n</ul>\n</li>\n<li><code>service/chime-sdk-meetings</code>: Updates service API and documentation</li>\n<li><code>service/databrew</code>: Updates service API, documentation, and paginators</li>\n<li><code>service/forecast</code>: Updates service API and documentation</li>\n<li><code>service/ivs</code>: Updates service API, documentation, and paginators</li>\n<li><code>service/kafka</code>: Updates service API and documentation</li>\n<li><code>service/lambda</code>: Updates service API and documentation\n<ul>\n<li>Added support for CLIENT_CERTIFICATE_TLS_AUTH and SERVER_ROOT_CA_CERTIFICATE as SourceAccessType for MSK and Kafka event source mappings.</li>\n</ul>\n</li>\n<li><code>service/models.lex.v2</code>: Updates service API and documentation</li>\n<li><code>service/monitoring</code>: Updates service API and documentation\n<ul>\n<li>CloudWatch Anomaly Detection now supports anomaly detectors that use metric math as input.</li>\n</ul>\n</li>\n<li><code>service/redshift-data</code>: Updates service API and documentation</li>\n</ul>\n<h1>Release v1.42.7 (2021-11-17)</h1>\n<h3>Service Client Updates</h3>\n<ul>\n<li><code>service/amplifybackend</code>: Updates service API and documentation</li>\n<li><code>service/apigateway</code>: Updates service documentation\n<ul>\n<li>Documentation updates for Amazon API Gateway.</li>\n</ul>\n</li>\n<li><code>service/appconfigdata</code>: Adds new service</li>\n<li><code>service/devops-guru</code>: Updates service paginators</li>\n<li><code>service/drs</code>: Updates service  ...
#     'reactions': {'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/comments/976309379',
#     'html_url': 'https://github.com/maddijoyce/terraform-provider-aws/pull/532#issuecomment-976309379',
#     'issue_url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/532',
#     'id': 976309379,
#     'node_id': 'IC_kwDOD3zkYs46MUyD',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-11-23T09:13:54Z',
#     'updated_at': '2021-11-23T09:13:54Z',
#     'author_association': 'NONE',
#     'body': 'Superseded by #534.',
#     'reactions': {'url': 'https://api.github.com/repos/maddijoyce/terraform-provider-aws/issues/comments/976309379/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-23T09:13:54Z'},
#  {'id': '19010929303',
#   'type': 'PushEvent',
#   'actor': {'id': 84472178,
#    'login': 'ChuntBot',
#    'display_login': 'ChuntBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ChuntBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84472178?'},
#   'repo': {'id': 368968787,
#    'name': 'ChuntBot/FeedArchive',
#    'url': 'https://api.github.com/repos/ChuntBot/FeedArchive'},
#   'payload': {'push_id': 8451517198,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '050179787fb1f26b19df06cb086bcb7ffc9b74cf',
#    'before': '7e681dad9c4d3982cd2046650fe2f6df4ab2037e',
#    'commits': [{'sha': '050179787fb1f26b19df06cb086bcb7ffc9b74cf',
#      'author': {'email': '84472178+ChuntBot@users.noreply.github.com',
#       'name': 'Chunt'},
#      'message': 'Add 2 ExploitDB entries of #securityfeed',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ChuntBot/FeedArchive/commits/050179787fb1f26b19df06cb086bcb7ffc9b74cf'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:13:55Z'}]

# %%
from IPython.display import JSON
JSON(response.json()[:5])

# %%
len(github_response)
# Out:
# 30

# %%
#login
github_response[3]["actor"]["login"]
# Out:
# 'abby-cyber'

# %% [markdown]
# ### Exercise:
#
# Extract the "login", the repo name and the event type for each event.

# %%
login = []
repo = []
event_type = []

for i in range(len(github_response)):
    login.append(github_response[i]["actor"]["login"])
    
for i in range(len(github_response)):
    repo.append(github_response[i]["repo"]["name"])
    
for i in range(len(github_response)):
    event_type.append(github_response[i]["type"])

# %%
# turn it into a pandas dataframe
pd.DataFrame(github_response).head()
# Out:
#             id         type  \
# 0  19010929495   WatchEvent
# 1  19010929515    PushEvent
# 2  19010929500    PushEvent
# 3  19010929493  CreateEvent
# 4  19010929483  CreateEvent
#
#                                                actor  \
# 0  {'id': 31913538, 'login': 'PENGsBIT', 'display...
# 1  {'id': 60386806, 'login': 'leanprover-communit...
# 2  {'id': 64638744, 'login': 'ksidyagin', 'displa...
# 3  {'id': 78209557, 'login': 'abby-cyber', 'displ...
# 4  {'id': 89975513, 'login': 'bhaskarboserackspac...
#
#                                                 repo  \
# 0  {'id': 173063554, 'name': 'alibaba/RedisShake'...
# 1  {'id': 257845141, 'name': 'leanprover-communit...
# 2  {'id': 430368965, 'name': 'ksidyagin/volodarsk...
# 3  {'id': 401959197, 'name': 'abby-cyber/nebula-d...
# 4  {'id': 233290577, 'name': 'rackerlabs/technica...
#
#                                              payload  public  \
# 0                              {'action': 'started'}    True
# 1  {'push_id': 8451516563, 'size': 1, 'distinct_s...    True
# 2  {'push_id': 8451517298, 'size': 1, 'distinct_s...    True
# 3  {'ref': 'add-whitespace-for-quick-start', 'ref...    True
# 4  {'ref': 'oracle_docker', 'ref_type': 'branch',...    True
#
#              created_at                                                org
# 0  2021-11-23T09:13:55Z  {'id': 1961952, 'login': 'alibaba', 'gravatar_...
# 1  2021-11-23T09:13:55Z  {'id': 41703605, 'login': 'leanprover-communit...
# 2  2021-11-23T09:13:55Z                                                NaN
# 3  2021-11-23T09:13:55Z                                                NaN
# 4  2021-11-23T09:13:55Z  {'id': 84293, 'login': 'rackerlabs', 'gravatar...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(github_response).head()
# Out:
#             id         type  public            created_at  actor.id  \
# 0  19010929495   WatchEvent    True  2021-11-23T09:13:55Z  31913538
# 1  19010929515    PushEvent    True  2021-11-23T09:13:55Z  60386806
# 2  19010929500    PushEvent    True  2021-11-23T09:13:55Z  64638744
# 3  19010929493  CreateEvent    True  2021-11-23T09:13:55Z  78209557
# 4  19010929483  CreateEvent    True  2021-11-23T09:13:55Z  89975513
#
#                 actor.login       actor.display_login actor.gravatar_id  \
# 0                  PENGsBIT                  PENGsBIT
# 1  leanprover-community-bot  leanprover-community-bot
# 2                 ksidyagin                 ksidyagin
# 3                abby-cyber                abby-cyber
# 4      bhaskarboserackspace      bhaskarboserackspace
#
#                                            actor.url  \
# 0              https://api.github.com/users/PENGsBIT
# 1  https://api.github.com/users/leanprover-commun...
# 2             https://api.github.com/users/ksidyagin
# 3            https://api.github.com/users/abby-cyber
# 4  https://api.github.com/users/bhaskarboserackspace
#
#                                     actor.avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/31913538?  ...
# 1  https://avatars.githubusercontent.com/u/60386806?  ...
# 2  https://avatars.githubusercontent.com/u/64638744?  ...
# 3  https://avatars.githubusercontent.com/u/78209557?  ...
# 4  https://avatars.githubusercontent.com/u/89975513?  ...
#
#    payload.comment.reactions.total_count payload.comment.reactions.+1  \
# 0                                    NaN                          NaN
# 1                                    NaN                          NaN
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
#
#   payload.comment.reactions.-1 payload.comment.reactions.laugh  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
#
#    payload.comment.reactions.hooray payload.comment.reactions.confused  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#   payload.comment.reactions.heart payload.comment.reactions.rocket  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
#
#   payload.comment.reactions.eyes  payload.comment.performed_via_github_app
# 0                            NaN                                       NaN
# 1                            NaN                                       NaN
# 2                            NaN                                       NaN
# 3                            NaN                                       NaN
# 4                            NaN                                       NaN
#
# [5 rows x 491 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'iss_position': {'latitude': '-39.3789', 'longitude': '32.3615'},
#  'message': 'success',
#  'timestamp': 1637659212}

# %% [markdown]
# ## Spotipy
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into an Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/app-settings/

# %% [markdown]
# #### Authentification
#
# Follow the wrapper for the API docs: https://spotipy.readthedocs.io/en/2.16.1/

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(
    client_credentials_manager=SpotifyClientCredentials(
    client_id="5b3311d52b2845cf9c3bf804ea93a3d2",
    client_secret="7cfe8f28ffbc4b66afe9ea86a10e5cbf"
    ))

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This function allows you to find songs with using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
JSON(results)

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: you know that because the dictionary is wrapped by square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features:

# %%
results["tracks"]["items"][0]["popularity"]
# Out:
# 81

# %% [markdown]
# This is how Spotify identifies individual songs: with an `uri`. (the `id` and the `url` are also ways to identify uniquely each song).

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chilli Peppers and store the `uri` of the songs and their names.

# %%
# send request and store the response
red_hot = sp.search(q="Red hot chili peppers", limit=10)

# initialize empty lists to store stuff later
list_of_uri = []
list_of_song_names = []

# iterate through the "items" (the songs), and append
# the "uri" and the "name" to the lists we created
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# print results
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS', 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx', 'spotify:track:1XxCiPw07rd1ytYnE7SoJI', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:4nRi0PlIpoy9SyySD1IDGY', 'spotify:track:2aibwv5hGXSgw7Yru8IYTO', 'spotify:track:4dzbGvxqQ1DsF6m6RUlPwg']
#
#
# ['Under the Bridge', 'Anthony Kiedis', 'Around the World', "Can't Stop", 'Buried Alive', "Road Trippin'", 'Californication', 'By the Way - Live', 'Snow (Hey Oh)', 'Pedigree']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results into a big list called `results`.

# %%
artists = ["Red hot chili peppers", "SCARR", "Whitney Houston"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
results
# Out:
# [{'tracks': {'href': 'https://api.spotify.com/v1/search?query=Red+hot+chili+peppers&type=track&offset=0&limit=10',
#    'items': [{'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/30Perjew8HyGkdSmqguYyg'},
#       'href': 'https://api.spotify.com/v1/albums/30Perjew8HyGkdSmqguYyg',
#       'id': '30Perjew8HyGkdSmqguYyg',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273153d79816d853f2694b2cc70',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02153d79816d853f2694b2cc70',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851153d79816d853f2694b2cc70',
#         'width': 64}],
#       'name': 'Blood Sugar Sex Magik (Deluxe Edition)',
#       'release_date': '1991-09-24',
#       'release_date_precision': 'day',
#       'total_tracks': 19,
#       'type': 'album',
#       'uri': 'spotify:album:30Perjew8HyGkdSmqguYyg'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 264306,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19901576'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3d9DChrdc6BOeFsbrZ3Is0'},
#      'href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#      'id': '3d9DChrdc6BOeFsbrZ3Is0',
#      'is_local': False,
#      'name': 'Under the Bridge',
#      'popularity': 81,
#      'preview_url': 'https://p.scdn.co/mp3-preview/90e41778392f27b6f7dd82db4c90916b3727aa6a?cid=faab70f9c2b24a689a326c3e0be9e549',
#      'track_number': 11,
#      'type': 'track',
#      'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#         'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#         'id': '0NB5HROxc8dDBXpkIi1v3d',
#         'name': 'Remi Wolf',
#         'type': 'artist',
#         'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7tJ8Wtej161vR0uCbGDiDR'},
#       'href': 'https://api.spotify.com/v1/albums/7tJ8Wtej161vR0uCbGDiDR',
#       'id': '7tJ8Wtej161vR0uCbGDiDR',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27316a6cb93e32bf2ae66b1f5b2',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0216a6cb93e32bf2ae66b1f5b2',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485116a6cb93e32bf2ae66b1f5b2',
#         'width': 64}],
#       'name': 'Juno',
#       'release_date': '2021-10-15',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:7tJ8Wtej161vR0uCbGDiDR'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#        'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#        'id': '0NB5HROxc8dDBXpkIi1v3d',
#        'name': 'Remi Wolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 171897,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUG12103572'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3xJu5hrOU9OvFQSGLQiwQS'},
#      'href': 'https://api.spotify.com/v1/tracks/3xJu5hrOU9OvFQSGLQiwQS',
#      'id': '3xJu5hrOU9OvFQSGLQiwQS',
#      'is_local': False,
#      'name': 'Anthony Kiedis',
#      'popularity': 60,
#      'preview_url': None,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0fLhefnjlIV3pGNF9Wo8CD'},
#       'href': 'https://api.spotify.com/v1/albums/0fLhefnjlIV3pGNF9Wo8CD',
#       'id': '0fLhefnjlIV3pGNF9Wo8CD',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a9249ebb15ca7a5b75f16a90',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a9249ebb15ca7a5b75f16a90',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a9249ebb15ca7a5b75f16a90',
#         'width': 64}],
#       'name': 'Californication',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:0fLhefnjlIV3pGNF9Wo8CD'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 239213,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900687'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1Y6DGcTCuMAtw8KB3h4W3q'},
#      'href': 'https://api.spotify.com/v1/tracks/1Y6DGcTCuMAtw8KB3h4W3q',
#      'id': '1Y6DGcTCuMAtw8KB3h4W3q',
#      'is_local': False,
#      'name': 'Around the World',
#      'popularity': 51,
#      'preview_url': 'https://p.scdn.co/mp3-preview/79ddc3851069cf64e6b11574b7414477ddf275d6?cid=faab70f9c2b24a689a326c3e0be9e549',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6deiaArbeoqp1xPEGdEKp1'},
#       'href': 'https://api.spotify.com/v1/albums/6deiaArbeoqp1xPEGdEKp1',
#       'id': '6deiaArbeoqp1xPEGdEKp1',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273de1af2785a83cc660155a0c4',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02de1af2785a83cc660155a0c4',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851de1af2785a83cc660155a0c4',
#         'width': 64}],
#       'name': 'By the Way (Deluxe Edition)',
#       'release_date': '2002-07-09',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:6deiaArbeoqp1xPEGdEKp1'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 269000,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB10201694'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3ZOEytgrvLwQaqXreDs2Jx'},
#      'href': 'https://api.spotify.com/v1/tracks/3ZOEytgrvLwQaqXreDs2Jx',
#      'id': '3ZOEytgrvLwQaqXreDs2Jx',
#      'is_local': False,
#      'name': "Can't Stop",
#      'popularity': 80,
#      'preview_url': 'https://p.scdn.co/mp3-preview/076f7d75404dfd18964d60da63d1855b192f3e62?cid=faab70f9c2b24a689a326c3e0be9e549',
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRYI6VqpkE3UwrDrAZL8L'},
#         'href': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L',
#         'id': '4xRYI6VqpkE3UwrDrAZL8L',
#         'name': 'Logic',
#         'type': 'artist',
#         'uri': 'spotify:artist:4xRYI6VqpkE3UwrDrAZL8L'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1Mk7Lei0Ra3hawezqmad5V'},
#       'href': 'https://api.spotify.com/v1/albums/1Mk7Lei0Ra3hawezqmad5V',
#       'id': '1Mk7Lei0Ra3hawezqmad5V',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a4c35326f6fe6676c10e31ac',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a4c35326f6fe6676c10e31ac',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a4c35326f6fe6676c10e31ac',
#         'width': 64}],
#       'name': 'Under Pressure (Deluxe)',
#       'release_date': '2014-10-21',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:1Mk7Lei0Ra3hawezqmad5V'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRYI6VqpkE3UwrDrAZL8L'},
#        'href': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L',
#        'id': '4xRYI6VqpkE3UwrDrAZL8L',
#        'name': 'Logic',
#        'type': 'artist',
#        'uri': 'spotify:artist:4xRYI6VqpkE3UwrDrAZL8L'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 337746,
#      'explicit': True,
#      'external_ids': {'isrc': 'USUM71414218'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0Kojfmpnf0A2yC1zyv39Zx'},
#      'href': 'https://api.spotify.com/v1/tracks/0Kojfmpnf0A2yC1zyv39Zx',
#      'id': '0Kojfmpnf0A2yC1zyv39Zx',
#      'is_local': False,
#      'name': 'Buried Alive',
#      'popularity': 53,
#      'preview_url': None,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#       'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#       'id': '2Y9IRtehByVkegoD7TcLfi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#         'width': 64}],
#       'name': 'Californication (Deluxe Edition)',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 204973,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900700'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1XxCiPw07rd1ytYnE7SoJI'},
#      'href': 'https://api.spotify.com/v1/tracks/1XxCiPw07rd1ytYnE7SoJI',
#      'id': '1XxCiPw07rd1ytYnE7SoJI',
#      'is_local': False,
#      'name': "Road Trippin'",
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/44653117c32f12cb2af30093736571893ff4c694?cid=faab70f9c2b24a689a326c3e0be9e549',
#      'track_number': 15,
#      'type': 'track',
#      'uri': 'spotify:track:1XxCiPw07rd1ytYnE7SoJI'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#       'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#       'id': '2Y9IRtehByVkegoD7TcLfi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#         'width': 64}],
#       'name': 'Californication (Deluxe Edition)',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 329733,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900690'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/48UPSzbZjgc449aqz8bxox'},
#      'href': 'https://api.spotify.com/v1/tracks/48UPSzbZjgc449aqz8bxox',
#      'id': '48UPSzbZjgc449aqz8bxox',
#      'is_local': False,
#      'name': 'Californication',
#      'popularity': 81,
#      'preview_url': 'https://p.scdn.co/mp3-preview/175ce440229d2fb5361756f3e68c9647b86a8eee?cid=faab70f9c2b24a689a326c3e0be9e549',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:48UPSzbZjgc449aqz8bxox'},
#     {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': ['CA', 'US'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4US5ARBYbzQI177Tc5J37t'},
#       'href': 'https://api.spotify.com/v1/albums/4US5ARBYbzQI177Tc5J37t',
#       'id': '4US5ARBYbzQI177Tc5J37t',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273c2244fca50540dc4df3b6bbf',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02c2244fca50540dc4df3b6bbf',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851c2244fca50540dc4df3b6bbf',
#         'width': 64}],
#       'name': 'The Rock & Roll Hall Of Fame: In Concert 2012 & 2013 (Live)',
#       'release_date': '2018-04-24',
#       'release_date_precision': 'day',
#       'total_tracks': 22,
#       'type': 'album',
#       'uri': 'spotify:album:4US5ARBYbzQI177Tc5J37t'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['CA', 'US'],
#      'disc_number': 1,
#      'duration_ms': 217351,
#      'explicit': False,
#      'external_ids': {'isrc': 'USYRC1800031'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4nRi0PlIpoy9SyySD1IDGY'},
#      'href': 'https://api.spotify.com/v1/tracks/4nRi0PlIpoy9SyySD1IDGY',
#      'id': '4nRi0PlIpoy9SyySD1IDGY',
#      'is_local': False,
#      'name': 'By the Way - Live',
#      'popularity': 10,
#      'preview_url': 'https://p.scdn.co/mp3-preview/e073ea994d91d77841fee33c8db3e1d76850beea?cid=faab70f9c2b24a689a326c3e0be9e549',
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:4nRi0PlIpoy9SyySD1IDGY'},
#     {'album': {'album_type': 'album',
# ...
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 277240,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18500147'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0t6DdFmFQhQYWhmfa5FJer'},
#      'href': 'https://api.spotify.com/v1/tracks/0t6DdFmFQhQYWhmfa5FJer',
#      'id': '0t6DdFmFQhQYWhmfa5FJer',
#      'is_local': False,
#      'name': 'You Give Good Love',
#      'popularity': 52,
#      'preview_url': 'https://p.scdn.co/mp3-preview/dc77dfeffba6def27cfaec208623ab82cc33cacc?cid=faab70f9c2b24a689a326c3e0be9e549',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0t6DdFmFQhQYWhmfa5FJer'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#         'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#         'id': '6XpaIBNiVzIetEPCWDvAFP',
#         'name': 'Whitney Houston',
#         'type': 'artist',
#         'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2MH37enG6IPvNK5QFLyKes'},
#       'href': 'https://api.spotify.com/v1/albums/2MH37enG6IPvNK5QFLyKes',
#       'id': '2MH37enG6IPvNK5QFLyKes',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732ae4fcec560ab559d6f5dc88',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022ae4fcec560ab559d6f5dc88',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512ae4fcec560ab559d6f5dc88',
#         'width': 64}],
#       'name': 'Whitney Houston',
#       'release_date': '1985-02-14',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:2MH37enG6IPvNK5QFLyKes'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#        'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#        'id': '6XpaIBNiVzIetEPCWDvAFP',
#        'name': 'Whitney Houston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 275533,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18500150'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5tdKaKLnC4SgtDZ6RlWeal'},
#      'href': 'https://api.spotify.com/v1/tracks/5tdKaKLnC4SgtDZ6RlWeal',
#      'id': '5tdKaKLnC4SgtDZ6RlWeal',
#      'is_local': False,
#      'name': 'How Will I Know',
#      'popularity': 70,
#      'preview_url': 'https://p.scdn.co/mp3-preview/4cfd0ab2b770e37313275d37788f687992b0ee17?cid=faab70f9c2b24a689a326c3e0be9e549',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:5tdKaKLnC4SgtDZ6RlWeal'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#         'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#         'id': '6XpaIBNiVzIetEPCWDvAFP',
#         'name': 'Whitney Houston',
#         'type': 'artist',
#         'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5Vdzprr5cOqXQo44eHeV7t'},
#       'href': 'https://api.spotify.com/v1/albums/5Vdzprr5cOqXQo44eHeV7t',
#       'id': '5Vdzprr5cOqXQo44eHeV7t',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273cc57e9b00b87dd0f6e868347',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02cc57e9b00b87dd0f6e868347',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851cc57e9b00b87dd0f6e868347',
#         'width': 64}],
#       'name': 'Whitney',
#       'release_date': '1987-06-02',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:5Vdzprr5cOqXQo44eHeV7t'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#        'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#        'id': '6XpaIBNiVzIetEPCWDvAFP',
#        'name': 'Whitney Houston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 305066,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18700115'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/19wadMw1A8XejDV4p5wMt1'},
#      'href': 'https://api.spotify.com/v1/tracks/19wadMw1A8XejDV4p5wMt1',
#      'id': '19wadMw1A8XejDV4p5wMt1',
#      'is_local': False,
#      'name': "Didn't We Almost Have It All",
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/7411cc6a36f98f46a2890f6f322605021db0f3c2?cid=faab70f9c2b24a689a326c3e0be9e549',
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:19wadMw1A8XejDV4p5wMt1'}],
#    'limit': 10,
#    'next': 'https://api.spotify.com/v1/search?query=Whitney+Houston&type=track&offset=10&limit=10',
#    'offset': 0,
#    'previous': None,
#    'total': 5827}}]

# %% [markdown]
# We can iterate through the `results` list and get the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Anthony Kiedis',
#  'Around the World',
#  "Can't Stop",
#  'Buried Alive',
#  "Road Trippin'",
#  'Californication',
#  'By the Way - Live',
#  'Snow (Hey Oh)',
#  'Pedigree',
#  'Scarred From Love',
#  'Emotionally Scarred',
#  'SCARR',
#  'Scarred',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred Island',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred',
#  'Rolling Loud (feat. Big Scarr, BigWalkDog)',
#  'Free Smoke (feat. Big Scarr)',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'The Star Spangled Banner (feat. The Florida Orchestra) - Live from Super Bowl XXV',
#  'Higher Love',
#  'I Look to You',
#  'I Will Always Love You',
#  'Exhale (Shoop Shoop) - from "Waiting to Exhale" - Original Soundtrack',
#  'I Have Nothing',
#  'You Give Good Love',
#  'How Will I Know',
#  "Didn't We Almost Have It All"]

# %% [markdown]
# #### Exploring the tracks

# %%
# Get artist id's for all the tracks you found
query = "Despacito"

despacito = sp.search(q = query, limit = 50)

# %%
despacito_artists = set()

for item in despacito["tracks"]["items"]:
    for artist in item["artists"]:
        despacito_artists.add(artist["uri"])

# %%
despacito["tracks"]["items"][2]["artists"][0]["name"]
# Out:
# 'Luis Fonsi'

# %%
despacito_artists
# Out:
# {'spotify:artist:0NxhAEPOSeCg6vypFr7yjU',
#  'spotify:artist:0QNakySWugkMvfwbDoaY9L',
#  'spotify:artist:0fIdQWpwzU2oEtsoyArDOL',
#  'spotify:artist:0r3y7sISJoUIfT5E85AYII',
#  'spotify:artist:1NiC1V6xc8OR1ERiIoCvtx',
#  'spotify:artist:1Uz4WPsI4VylKT6lhJiDO5',
#  'spotify:artist:1emgbX82aLN8eCS3AnXFfC',
#  'spotify:artist:1mX1TWKpNxDSAH16LgDfiR',
#  'spotify:artist:1qwVM2JnEMXbKgvZESGsRn',
#  'spotify:artist:1rVo9h17cHhWerDiZj0yXH',
#  'spotify:artist:1sJhbiQRSIKZeTYEZfzBSV',
#  'spotify:artist:1uNFoZAHBGtllmzznpCI3s',
#  'spotify:artist:1uj8EOCKAXn4w2TR7CVnQb',
#  'spotify:artist:26AHtbjWKiwYzsoGoUZq53',
#  'spotify:artist:2T06whb4s6UiufL1j5Qtz9',
#  'spotify:artist:2VAjBQ6cM2faT2UKxONV93',
#  'spotify:artist:3YfvowVavHTzXLKmKaYM1c',
#  'spotify:artist:3YrM00mKs7wqOtBPmeSoEo',
#  'spotify:artist:3vOJJbGGUOtC9csissiL0G',
#  'spotify:artist:4KLOMib6zqzNayKwLWTs2Q',
#  'spotify:artist:4L5SLCIDWPPNGzrLraYCOS',
#  'spotify:artist:4N5fp4zhTsVITZTVfsXpc2',
#  'spotify:artist:4V8Sr092TqfHkfAA5fXXqG',
#  'spotify:artist:4VMYDCV2IEDYJArk749S6m',
#  'spotify:artist:4fdxbJLSNRIMkMGbLs5QPF',
#  'spotify:artist:4j4Lq1ut4h3H3eTIubtyog',
#  'spotify:artist:5DsbNI5ZIDIWjmsAdaYvZ2',
#  'spotify:artist:5HPu6u2rDA0f6jp51xZAEq',
#  'spotify:artist:5KWOCu1saEHAhPiLKlOLIy',
#  'spotify:artist:5tqJLLaSDpdhDAwqWgAdXM',
#  'spotify:artist:62rnGiDozQmBBk5yM21yOC',
#  'spotify:artist:6Fi8CHfO8WGtu3yO8c2Mc4',
#  'spotify:artist:6MERXsiRbur2oJZFgYRDKz',
#  'spotify:artist:6QtqvuYuaOJy4te3nfkHKK',
#  'spotify:artist:6RTlv2UCWtRggV0rIo5TrN',
#  'spotify:artist:6U3ybJ9UHNKEdsH7ktGBZ7',
#  'spotify:artist:6dBIk14xcZqU0cRsyjXNkX',
#  'spotify:artist:6mU8ucezzms5I2kNH6HNlu',
#  'spotify:artist:6wBOZ9D65AcqUlfKUqsQ7R',
#  'spotify:artist:72iuahEAHKaMzDXKVw6e8P',
#  'spotify:artist:738wLrAtLtCtFOLvQBXOXp',
#  'spotify:artist:7CQwac16i1W5ej8YpuL3dv',
#  'spotify:artist:7dTPvuNcEXLkQ1XiAuiWIP',
#  'spotify:artist:7p3ipw2PvGG0X2x6zL1DLO',
#  'spotify:artist:7y33enVLfDvft6HGNmcxdV'}

# %% [markdown]
# ### Playlists

# %%
my_playlist = sp.user_playlist_tracks(user="spotify",
                                      playlist_id="https://open.spotify.com/playlist/24T3swe0HN7JWLfsDcakHw?si=ce24270cef314a9a")

# %% [markdown]
# Extract all songs IDs from a playlist

# %%
my_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/24T3swe0HN7JWLfsDcakHw/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-01-30T09:02:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CIMQHirSU0MQqyYHq0eOx'},
#        'href': 'https://api.spotify.com/v1/artists/2CIMQHirSU0MQqyYHq0eOx',
#        'id': '2CIMQHirSU0MQqyYHq0eOx',
#        'name': 'deadmau5',
#        'type': 'artist',
#        'uri': 'spotify:artist:2CIMQHirSU0MQqyYHq0eOx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6WJvrBlL3zgu4mVoKyvMkl'},
#      'href': 'https://api.spotify.com/v1/albums/6WJvrBlL3zgu4mVoKyvMkl',
#      'id': '6WJvrBlL3zgu4mVoKyvMkl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d49d976721f4dc6b3c6225ad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d49d976721f4dc6b3c6225ad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d49d976721f4dc6b3c6225ad',
#        'width': 64}],
#      'name': 'For Lack Of A Better Name',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6WJvrBlL3zgu4mVoKyvMkl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CIMQHirSU0MQqyYHq0eOx'},
#       'href': 'https://api.spotify.com/v1/artists/2CIMQHirSU0MQqyYHq0eOx',
#       'id': '2CIMQHirSU0MQqyYHq0eOx',
#       'name': 'deadmau5',
#       'type': 'artist',
#       'uri': 'spotify:artist:2CIMQHirSU0MQqyYHq0eOx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 3959893,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBTDG0900149'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3v4HvdYsdAc8K9Fy5SdyGe'},
#     'href': 'https://api.spotify.com/v1/tracks/3v4HvdYsdAc8K9Fy5SdyGe',
#     'id': '3v4HvdYsdAc8K9Fy5SdyGe',
#     'is_local': False,
#     'name': 'For Lack Of A Better Name - Mixed Version',
#     'popularity': 21,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3v4HvdYsdAc8K9Fy5SdyGe'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 387506,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5eS6pTvDNOvh2kyxeZtK3r'},
#     'href': 'https://api.spotify.com/v1/tracks/5eS6pTvDNOvh2kyxeZtK3r',
#     'id': '5eS6pTvDNOvh2kyxeZtK3r',
#     'is_local': False,
#     'name': 'Robot Rock / Oh Yeah',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7a72ef3ab554e6a0aec213fbfa1756d444edaf9e?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5eS6pTvDNOvh2kyxeZtK3r'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 329653,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBDUW0700002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4IdiGMOzEYXOh2897XOV8i'},
#     'href': 'https://api.spotify.com/v1/tracks/4IdiGMOzEYXOh2897XOV8i',
#     'id': '4IdiGMOzEYXOh2897XOV8i',
#     'is_local': False,
#     'name': 'Touch It / Technologic',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/71c958b90ea51e487f842e132236008c5986ef9e?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4IdiGMOzEYXOh2897XOV8i'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 290840,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1E8S3CSv20KrKT0C1yAjkO'},
#     'href': 'https://api.spotify.com/v1/tracks/1E8S3CSv20KrKT0C1yAjkO',
#     'id': '1E8S3CSv20KrKT0C1yAjkO',
#     'is_local': False,
#     'name': 'Television Rules the Nation / Crescendolls',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0eaa9f74ca537bbaf7e34f970206868faa4ce3cb?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1E8S3CSv20KrKT0C1yAjkO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 421600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700004'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3n4ow4XGzwSIPxA3JHLF9p'},
#     'href': 'https://api.spotify.com/v1/tracks/3n4ow4XGzwSIPxA3JHLF9p',
#     'id': '3n4ow4XGzwSIPxA3JHLF9p',
#     'is_local': False,
#     'name': 'Too Long / Steam Machine',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bb029a3b48b31f515838b09ff2065dd724467527?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3n4ow4XGzwSIPxA3JHLF9p'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 342626,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RByQFt9Mlo8hDYJ921tCv'},
#     'href': 'https://api.spotify.com/v1/tracks/5RByQFt9Mlo8hDYJ921tCv',
#     'id': '5RByQFt9Mlo8hDYJ921tCv',
#     'is_local': False,
#     'name': 'Around the World / Harder, Better, Faster, Stronger',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/029d59d938437b6735214573954dcc488c541264?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5RByQFt9Mlo8hDYJ921tCv'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 431506,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700006'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Ons6C3wXBMi8nYpLBMlVe'},
#     'href': 'https://api.spotify.com/v1/tracks/3Ons6C3wXBMi8nYpLBMlVe',
#     'id': '3Ons6C3wXBMi8nYpLBMlVe',
#     'is_local': False,
#     'name': "Burnin' / Too Long",
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a5b507a0f17ee87689ba19d8585cd2d1a8a01bf6?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3Ons6C3wXBMi8nYpLBMlVe'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
# ...
#       'href': 'https://api.spotify.com/v1/artists/02zMQvIvPXbVOLDdFqbFUn',
#       'id': '02zMQvIvPXbVOLDdFqbFUn',
#       'name': 'Les Rythmes Digitales',
#       'type': 'artist',
#       'uri': 'spotify:artist:02zMQvIvPXbVOLDdFqbFUn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AM',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CH',
#      'CL',
#      'CO',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GB',
#      'GE',
#      'GR',
#      'GY',
#      'HR',
#      'HU',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JO',
#      'KG',
#      'KI',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MH',
#      'MK',
#      'MT',
#      'NL',
#      'NO',
#      'NR',
#      'NZ',
#      'OM',
#      'PE',
#      'PG',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SB',
#      'SE',
#      'SI',
#      'SK',
#      'SM',
#      'SR',
#      'TJ',
#      'TO',
#      'TR',
#      'TV',
#      'UA',
#      'UY',
#      'UZ',
#      'VE',
#      'VU',
#      'WS',
#      'XK'],
#     'disc_number': 2,
#     'duration_ms': 351720,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCFC9900071'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1NDQosq5Ge6nGTPkdDj3Al'},
#     'href': 'https://api.spotify.com/v1/tracks/1NDQosq5Ge6nGTPkdDj3Al',
#     'id': '1NDQosq5Ge6nGTPkdDj3Al',
#     'is_local': False,
#     'name': 'Jacques Your Body - Cassius Remix Edit',
#     'popularity': 5,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b1ba40c99b521e2b2e3fb2a3ef8bf73ae6a54830?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:1NDQosq5Ge6nGTPkdDj3Al'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-24T06:35:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2U33UlGhnPqg3B5xJTn3zm'},
#        'href': 'https://api.spotify.com/v1/artists/2U33UlGhnPqg3B5xJTn3zm',
#        'id': '2U33UlGhnPqg3B5xJTn3zm',
#        'name': 'Wamdue Project',
#        'type': 'artist',
#        'uri': 'spotify:artist:2U33UlGhnPqg3B5xJTn3zm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/76dgPMKh0jMhFDbWeNF365'},
#      'href': 'https://api.spotify.com/v1/albums/76dgPMKh0jMhFDbWeNF365',
#      'id': '76dgPMKh0jMhFDbWeNF365',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730799754aff66bb4ab0694f5e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020799754aff66bb4ab0694f5e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510799754aff66bb4ab0694f5e',
#        'width': 64}],
#      'name': 'King Of My Castle',
#      'release_date': '1998',
#      'release_date_precision': 'year',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:76dgPMKh0jMhFDbWeNF365'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2U33UlGhnPqg3B5xJTn3zm'},
#       'href': 'https://api.spotify.com/v1/artists/2U33UlGhnPqg3B5xJTn3zm',
#       'id': '2U33UlGhnPqg3B5xJTn3zm',
#       'name': 'Wamdue Project',
#       'type': 'artist',
#       'uri': 'spotify:artist:2U33UlGhnPqg3B5xJTn3zm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Mry1TcXvK97hkYf7F74zn'},
#       'href': 'https://api.spotify.com/v1/artists/0Mry1TcXvK97hkYf7F74zn',
#       'id': '0Mry1TcXvK97hkYf7F74zn',
#       'name': 'Roy Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Mry1TcXvK97hkYf7F74zn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 299333,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSR39958301'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4XZwpHpscrMkbpQPqjnwRJ'},
#     'href': 'https://api.spotify.com/v1/tracks/4XZwpHpscrMkbpQPqjnwRJ',
#     'id': '4XZwpHpscrMkbpQPqjnwRJ',
#     'is_local': False,
#     'name': "King Of My Castle - Roy Malone's King Mix",
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e7bdc5268a3058b2a5016b4427364e99d75e3344?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4XZwpHpscrMkbpQPqjnwRJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-10-01T12:31:29Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2fBURuq7FrlH6z5F92mpOl'},
#        'href': 'https://api.spotify.com/v1/artists/2fBURuq7FrlH6z5F92mpOl',
#        'id': '2fBURuq7FrlH6z5F92mpOl',
#        'name': 'Digitalism',
#        'type': 'artist',
#        'uri': 'spotify:artist:2fBURuq7FrlH6z5F92mpOl'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/50MnC37ZrDB6U94K6M1do8'},
#      'href': 'https://api.spotify.com/v1/albums/50MnC37ZrDB6U94K6M1do8',
#      'id': '50MnC37ZrDB6U94K6M1do8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f60348430844f50c21ebfae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f60348430844f50c21ebfae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f60348430844f50c21ebfae',
#        'width': 64}],
#      'name': 'Idealism',
#      'release_date': '2007-05-09',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:50MnC37ZrDB6U94K6M1do8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2fBURuq7FrlH6z5F92mpOl'},
#       'href': 'https://api.spotify.com/v1/artists/2fBURuq7FrlH6z5F92mpOl',
#       'id': '2fBURuq7FrlH6z5F92mpOl',
#       'name': 'Digitalism',
#       'type': 'artist',
#       'uri': 'spotify:artist:2fBURuq7FrlH6z5F92mpOl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 250693,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRU700700010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2VbIou1DtUewZVgfte6kIW'},
#     'href': 'https://api.spotify.com/v1/tracks/2VbIou1DtUewZVgfte6kIW',
#     'id': '2VbIou1DtUewZVgfte6kIW',
#     'is_local': False,
#     'name': 'Idealistic',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d0200afb7130c3d24b95249e234df9f7db6e5fda?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2VbIou1DtUewZVgfte6kIW'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 73}

# %%
my_playlist["items"][0]["track"]["uri"]
# Out:
# 'spotify:track:3v4HvdYsdAc8K9Fy5SdyGe'

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %%
sp.audio_features("spotify:track:3d9DChrdc6BOeFsbrZ3Is0")
# Out:
# [{'danceability': 0.559,
#   'energy': 0.345,
#   'key': 4,
#   'loudness': -13.496,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.0576,
#   'instrumentalness': 0.000105,
#   'liveness': 0.141,
#   'valence': 0.458,
#   'tempo': 84.581,
#   'type': 'audio_features',
#   'id': '3d9DChrdc6BOeFsbrZ3Is0',
#   'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0',
#   'track_href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d9DChrdc6BOeFsbrZ3Is0',
#   'duration_ms': 264307,
#   'time_signature': 4}]

# %% [markdown]
# ### Exercise: Create a function that takes a song name and returns its audio features

# %%
#function building
def get_audio_feat_song(song_name):
    result = sp.search(q=song_name, limit=1)
    uri = result["tracks"]["items"][0]["uri"]
    return sp.audio_features(uri)

# %%
get_audio_feat_song("Sailing to Philadelphia")
# Out:
# [{'danceability': 0.589,
#   'energy': 0.484,
#   'key': 6,
#   'loudness': -10.126,
#   'mode': 0,
#   'speechiness': 0.0249,
#   'acousticness': 0.641,
#   'instrumentalness': 0.107,
#   'liveness': 0.0873,
#   'valence': 0.149,
#   'tempo': 99.067,
#   'type': 'audio_features',
#   'id': '4eA4i2Uf0DDIkpyesj98Ag',
#   'uri': 'spotify:track:4eA4i2Uf0DDIkpyesj98Ag',
#   'track_href': 'https://api.spotify.com/v1/tracks/4eA4i2Uf0DDIkpyesj98Ag',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eA4i2Uf0DDIkpyesj98Ag',
#   'duration_ms': 353120,
#   'time_signature': 4}]

# %%
result.keys()
# Out:
# dict_keys(['tracks'])

# %%
result["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:7rpNuuoMbid56XkDsx2FjE'

# %% [markdown]
# ### Exercise: Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have ot be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Now collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %%
playlists = ["https://open.spotify.com/playlist/0ce6Rmxf7QXroqa1wzjWY8?si=05b8e416dedd4894",
             "https://open.spotify.com/playlist/2PjVPkj4a9kBvQIXaZ6UUt?si=c83fe4d8a4974095",
             "https://open.spotify.com/playlist/1h0CEZCm6IbFTbxThn6Xcs?si=549db4d4f4ca4c18",
             "https://open.spotify.com/playlist/37i9dQZF1DX7Mq3mO5SSDc?si=55c443251302424e"
            ]

# %%
results = []

for p in playlists:
    results.append(sp.playlist_tracks(p))

# %%
results[0]["items"]
# Out:
# [{'added_at': '2021-09-22T07:34:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#       'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#       'id': '579T5fNgfbDetyamUTAetw',
#       'name': 'S+C+A+R+R',
#       'type': 'artist',
#       'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ZwTPVgvwIMxJh2GAdsaaP'},
#     'href': 'https://api.spotify.com/v1/albums/5ZwTPVgvwIMxJh2GAdsaaP',
#     'id': '5ZwTPVgvwIMxJh2GAdsaaP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27331df83ec065ed0a42cc82670',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0231df83ec065ed0a42cc82670',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485131df83ec065ed0a42cc82670',
#       'width': 64}],
#     'name': 'You\'re the One (From "I Lost My Body")',
#     'release_date': '2019-10-31',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5ZwTPVgvwIMxJh2GAdsaaP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#      'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#      'id': '579T5fNgfbDetyamUTAetw',
#      'name': 'S+C+A+R+R',
#      'type': 'artist',
#      'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 167986,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR6F31902770'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5Tnx4R7Gwj1LZsfssfzchh'},
#    'href': 'https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1LZsfssfzchh',
#    'id': '5Tnx4R7Gwj1LZsfssfzchh',
#    'is_local': False,
#    'name': 'You\'re the One - From "I Lost My Body"',
#    'popularity': 37,
#    'preview_url': 'https://p.scdn.co/mp3-preview/95301c6db23d3e35deda12970ef6bdc9f2d71579?cid=faab70f9c2b24a689a326c3e0be9e549',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:35:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#       'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#       'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#       'name': 'Manchester Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4hruYceqit29o6m4arpAql'},
#     'href': 'https://api.spotify.com/v1/albums/4hruYceqit29o6m4arpAql',
#     'id': '4hruYceqit29o6m4arpAql',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736827146a676dafc0357fa665',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026827146a676dafc0357fa665',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516827146a676dafc0357fa665',
#       'width': 64}],
#     'name': 'A Black Mile To The Surface',
#     'release_date': '2017-07-28',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:4hruYceqit29o6m4arpAql'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#      'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#      'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#      'name': 'Manchester Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 328933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USC4R1702133'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5eKfpH2dQ7FltCqb7LWEGJ'},
#    'href': 'https://api.spotify.com/v1/tracks/5eKfpH2dQ7FltCqb7LWEGJ',
#    'id': '5eKfpH2dQ7FltCqb7LWEGJ',
#    'is_local': False,
#    'name': 'The Alien',
#    'popularity': 47,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:35:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YwaTXvuTkyUrGPbz4jEYg'},
#       'href': 'https://api.spotify.com/v1/artists/4YwaTXvuTkyUrGPbz4jEYg',
#       'id': '4YwaTXvuTkyUrGPbz4jEYg',
#       'name': 'Nina And Frederik',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YwaTXvuTkyUrGPbz4jEYg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/63obBSI5HlMFoawrrq8RDG'},
#     'href': 'https://api.spotify.com/v1/albums/63obBSI5HlMFoawrrq8RDG',
#     'id': '63obBSI5HlMFoawrrq8RDG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a287436c88bfedf3892dcaea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a287436c88bfedf3892dcaea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a287436c88bfedf3892dcaea',
#       'width': 64}],
#     'name': 'Vintage World Nº10- EPs Collectors "Oh, Pecador" "Oh, Sinner Man"',
#     'release_date': '1958-05-06',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:63obBSI5HlMFoawrrq8RDG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YwaTXvuTkyUrGPbz4jEYg'},
#      'href': 'https://api.spotify.com/v1/artists/4YwaTXvuTkyUrGPbz4jEYg',
#      'id': '4YwaTXvuTkyUrGPbz4jEYg',
#      'name': 'Nina And Frederik',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YwaTXvuTkyUrGPbz4jEYg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 145773,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA560979249'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0R3OcHrzq3f8raukyZgTAc'},
#    'href': 'https://api.spotify.com/v1/tracks/0R3OcHrzq3f8raukyZgTAc',
#    'id': '0R3OcHrzq3f8raukyZgTAc',
#    'is_local': False,
#    'name': 'Oh, Pecador (Oh, Sinne Man)',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5a1f140ce93647c88b874627f0515bc739aae64a?cid=faab70f9c2b24a689a326c3e0be9e549',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0R3OcHrzq3f8raukyZgTAc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:36:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#       'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#       'id': '2G7QgTep5IsJHGHm1hXygD',
#       'name': 'Kid Francescoli',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4iII9nfzjxOYQFp8PyV6HD'},
#     'href': 'https://api.spotify.com/v1/albums/4iII9nfzjxOYQFp8PyV6HD',
#     'id': '4iII9nfzjxOYQFp8PyV6HD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737fc1ed797a7ef1dd805b5bc5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027fc1ed797a7ef1dd805b5bc5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517fc1ed797a7ef1dd805b5bc5',
#       'width': 64}],
#     'name': 'Play Me Again',
#     'release_date': '2017-03-03',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:4iII9nfzjxOYQFp8PyV6HD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#      'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#      'id': '2G7QgTep5IsJHGHm1hXygD',
#      'name': 'Kid Francescoli',
#      'type': 'artist',
#      'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 390638,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRP621600280'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/24upABZ8A0sAepfu91sEYr'},
#    'href': 'https://api.spotify.com/v1/tracks/24upABZ8A0sAepfu91sEYr',
#    'id': '24upABZ8A0sAepfu91sEYr',
#    'is_local': False,
#    'name': 'Moon (And It Went Like)',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/dcad19ab187c730cb3ad678695db21baf0137ac2?cid=faab70f9c2b24a689a326c3e0be9e549',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:24upABZ8A0sAepfu91sEYr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:36:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#       'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#       'id': '4aEnNH9PuU1HF3TsZTru54',
#       'name': 'Caribou',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1NqhnYAVqlHuPG2OlgKSZy'},
#     'href': 'https://api.spotify.com/v1/albums/1NqhnYAVqlHuPG2OlgKSZy',
#     'id': '1NqhnYAVqlHuPG2OlgKSZy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273db02bfcbd6808d71afb2a3bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02db02bfcbd6808d71afb2a3bf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851db02bfcbd6808d71afb2a3bf',
#       'width': 64}],
#     'name': 'Never Come Back',
#     'release_date': '2020-01-28',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:1NqhnYAVqlHuPG2OlgKSZy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#      'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#      'id': '4aEnNH9PuU1HF3TsZTru54',
#      'name': 'Caribou',
#      'type': 'artist',
#      'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 305480,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DED622000007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7IBrKDuBlyz3vW9JFCux10'},
#    'href': 'https://api.spotify.com/v1/tracks/7IBrKDuBlyz3vW9JFCux10',
#    'id': '7IBrKDuBlyz3vW9JFCux10',
#    'is_local': False,
#    'name': 'Never Come Back',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7IBrKDuBlyz3vW9JFCux10'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:36:57Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#       'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#       'id': '6wH6iStAh4KIaWfuhf0NYM',
#       'name': 'Manu Chao',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6sLpbLsD1LlXnlCRjt8YuE'},
#     'href': 'https://api.spotify.com/v1/albums/6sLpbLsD1LlXnlCRjt8YuE',
#     'id': '6sLpbLsD1LlXnlCRjt8YuE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27381d487c754295e61521aadcc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0281d487c754295e61521aadcc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485181d487c754295e61521aadcc',
#       'width': 64}],
#     'name': 'Proxima Estacion : Esperanza',
#     'release_date': '2001',
#     'release_date_precision': 'year',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:6sLpbLsD1LlXnlCRjt8YuE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#      'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#      'id': '6wH6iStAh4KIaWfuhf0NYM',
#      'name': 'Manu Chao',
#      'type': 'artist',
#      'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 114920,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR84R0100008'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ecVMxkn0sJ3nlx1uS0IVN'},
#    'href': 'https://api.spotify.com/v1/tracks/3ecVMxkn0sJ3nlx1uS0IVN',
#    'id': '3ecVMxkn0sJ3nlx1uS0IVN',
#    'is_local': False,
#    'name': 'Trapped By Love',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:3ecVMxkn0sJ3nlx1uS0IVN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:50:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#    'href': 'https://api.spotify.com/v1/users/1269546383',
#    'id': '1269546383',
#    'type': 'user',
#    'uri': 'spotify:user:1269546383'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#       'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#       'id': '5v74mT11KGJqadf9sLw4dA',
#       'name': 'Cannonball Adderley',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5JpHin9lKOyizuJhKxaHWp'},
#     'href': 'https://api.spotify.com/v1/albums/5JpHin9lKOyizuJhKxaHWp',
#     'id': '5JpHin9lKOyizuJhKxaHWp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27385827d636962ea87b858ab32',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0285827d636962ea87b858ab32',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485185827d636962ea87b858ab32',
#       'width': 64}],
#     'name': 'Jazz Profile: Cannonball Adderley',
#     'release_date': '1997-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:5JpHin9lKOyizuJhKxaHWp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#      'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#      'id': '5v74mT11KGJqadf9sLw4dA',
#      'name': 'Cannonball Adderley',
#      'type': 'artist',
#      'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 313200,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA29000136'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6NF8MZ2trxckVBr82pyyPt'},
#    'href': 'https://api.spotify.com/v1/tracks/6NF8MZ2trxckVBr82pyyPt',
#    'id': '6NF8MZ2trxckVBr82pyyPt',
#    'is_local': False,
#    'name': 'Mercy, Mercy, Mercy',
#    'popularity': 55,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:6NF8MZ2trxckVBr82pyyPt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:51:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#    'href': 'https://api.spotify.com/v1/users/1269546383',
#    'id': '1269546383',
#    'type': 'user',
#    'uri': 'spotify:user:1269546383'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#       'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#       'id': '3ayds6VIVBx3CU5NSNCDbq',
#       'name': 'Jacques Dutronc',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2S4mgB4hHSszPRGoYrGJ0d'},
#     'href': 'https://api.spotify.com/v1/albums/2S4mgB4hHSszPRGoYrGJ0d',
#     'id': '2S4mgB4hHSszPRGoYrGJ0d',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a28387fcc6e1c7ed11d82022',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a28387fcc6e1c7ed11d82022',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a28387fcc6e1c7ed11d82022',
#       'width': 64}],
#     'name': "L' aventurier",
#     'release_date': '1969-06-30',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2S4mgB4hHSszPRGoYrGJ0d'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#      'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#      'id': '3ayds6VIVBx3CU5NSNCDbq',
#      'name': 'Jacques Dutronc',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 155600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRZ196900030'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6FwkZ5lYdCUh1mzI1Bhojn'},
#    'href': 'https://api.spotify.com/v1/tracks/6FwkZ5lYdCUh1mzI1Bhojn',
#    'id': '6FwkZ5lYdCUh1mzI1Bhojn',
#    'is_local': False,
#    'name': 'Le responsable',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/57a0e4a3ae296a7e3e75205e2d04c76f8394637a?cid=faab70f9c2b24a689a326c3e0be9e549',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6FwkZ5lYdCUh1mzI1Bhojn'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:51:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#    'href': 'https://api.spotify.com/v1/users/1269546383',
#    'id': '1269546383',
#    'type': 'user',
#    'uri': 'spotify:user:1269546383'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#       'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#       'id': '2AR42Ur9PcchQDtEdwkv4L',
#       'name': 'Floating Points',
#       'type': 'artist',
#       'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1WwZwdTICfaZI51BIIEN9z'},
#     'href': 'https://api.spotify.com/v1/albums/1WwZwdTICfaZI51BIIEN9z',
#     'id': '1WwZwdTICfaZI51BIIEN9z',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d03dff7f5eeee485e5a45f62',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d03dff7f5eeee485e5a45f62',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d03dff7f5eeee485e5a45f62',
#       'width': 64}],
#     'name': 'Crush',
#     'release_date': '2019-10-18',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1WwZwdTICfaZI51BIIEN9z'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#      'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#      'id': '2AR42Ur9PcchQDtEdwkv4L',
#      'name': 'Floating Points',
#      'type': 'artist',
#      'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
# ...
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0kelpiZssyYlVNks8cHEth'},
#     'href': 'https://api.spotify.com/v1/albums/0kelpiZssyYlVNks8cHEth',
#     'id': '0kelpiZssyYlVNks8cHEth',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734d5ac815f4676b21c60bfdc8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024d5ac815f4676b21c60bfdc8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514d5ac815f4676b21c60bfdc8',
#       'width': 64}],
#     'name': 'Eu Vou Fazer uma Macumba Pra Te Amarrar, Maldito!',
#     'release_date': '2015-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0kelpiZssyYlVNks8cHEth'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#      'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#      'id': '7qmf5YAQYjfjBF9C7kkjzs',
#      'name': 'Johnny Hooker',
#      'type': 'artist',
#      'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 285000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'uscgh1563538'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7uSdpAkxgB0948bW7yjjJO'},
#    'href': 'https://api.spotify.com/v1/tracks/7uSdpAkxgB0948bW7yjjJO',
#    'id': '7uSdpAkxgB0948bW7yjjJO',
#    'is_local': False,
#    'name': 'Amor Marginal',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d763ebf13b84079b55cbee99c0c2fb29c0938ff7?cid=faab70f9c2b24a689a326c3e0be9e549',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7uSdpAkxgB0948bW7yjjJO'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:53:52Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/shokoshock'},
#    'href': 'https://api.spotify.com/v1/users/shokoshock',
#    'id': 'shokoshock',
#    'type': 'user',
#    'uri': 'spotify:user:shokoshock'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#       'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#       'id': '0YMeriqrS3zgsX24nfY0F0',
#       'name': 'The Tragically Hip',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6fRGXiRnTyLLRDXpXkrK1n'},
#     'href': 'https://api.spotify.com/v1/albums/6fRGXiRnTyLLRDXpXkrK1n',
#     'id': '6fRGXiRnTyLLRDXpXkrK1n',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273eb5ebaaa20f7d208ce1caa14',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02eb5ebaaa20f7d208ce1caa14',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851eb5ebaaa20f7d208ce1caa14',
#       'width': 64}],
#     'name': 'Yer Favourites',
#     'release_date': '2005-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 37,
#     'type': 'album',
#     'uri': 'spotify:album:6fRGXiRnTyLLRDXpXkrK1n'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#      'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#      'id': '0YMeriqrS3zgsX24nfY0F0',
#      'name': 'The Tragically Hip',
#      'type': 'artist',
#      'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 225426,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAM199600015'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5nC2BQzszGGkZi7cvxFzH4'},
#    'href': 'https://api.spotify.com/v1/tracks/5nC2BQzszGGkZi7cvxFzH4',
#    'id': '5nC2BQzszGGkZi7cvxFzH4',
#    'is_local': False,
#    'name': 'Ahead By A Century',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5nC2BQzszGGkZi7cvxFzH4'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T13:02:30Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/vaxgmeceb7pigybrcc3fdlhiw'},
#    'href': 'https://api.spotify.com/v1/users/vaxgmeceb7pigybrcc3fdlhiw',
#    'id': 'vaxgmeceb7pigybrcc3fdlhiw',
#    'type': 'user',
#    'uri': 'spotify:user:vaxgmeceb7pigybrcc3fdlhiw'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#       'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#       'id': '7zsin6IgVsR1rqSRCNYDwq',
#       'name': 'Family of the Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/14SCnv027L0HidHq0URIDu'},
#     'href': 'https://api.spotify.com/v1/albums/14SCnv027L0HidHq0URIDu',
#     'id': '14SCnv027L0HidHq0URIDu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731980a53c08d4911caa77d249',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021980a53c08d4911caa77d249',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511980a53c08d4911caa77d249',
#       'width': 64}],
#     'name': 'Loma Vista',
#     'release_date': '2012-07-10',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:14SCnv027L0HidHq0URIDu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#      'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#      'id': '7zsin6IgVsR1rqSRCNYDwq',
#      'name': 'Family of the Year',
#      'type': 'artist',
#      'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 190280,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAN111200237'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6GRDI9suQHikFP6euIXnpq'},
#    'href': 'https://api.spotify.com/v1/tracks/6GRDI9suQHikFP6euIXnpq',
#    'id': '6GRDI9suQHikFP6euIXnpq',
#    'is_local': False,
#    'name': 'Hero',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3d1f4e7938a250e489290ca27e1ebc9b511c1cf4?cid=faab70f9c2b24a689a326c3e0be9e549',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:6GRDI9suQHikFP6euIXnpq'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-29T14:22:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/8em1nqrnfspx3alyw0rz3ggn1'},
#    'href': 'https://api.spotify.com/v1/users/8em1nqrnfspx3alyw0rz3ggn1',
#    'id': '8em1nqrnfspx3alyw0rz3ggn1',
#    'type': 'user',
#    'uri': 'spotify:user:8em1nqrnfspx3alyw0rz3ggn1'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#       'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#       'id': '58r1rB5t3VF5X6yXGPequV',
#       'name': 'Maverick City Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0prxUuXzlIyjSJU9ej003n'},
#     'href': 'https://api.spotify.com/v1/albums/0prxUuXzlIyjSJU9ej003n',
#     'id': '0prxUuXzlIyjSJU9ej003n',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732176cda6fb0f4db7dbb6f1fb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022176cda6fb0f4db7dbb6f1fb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512176cda6fb0f4db7dbb6f1fb',
#       'width': 64}],
#     'name': 'Maverick City Vol. 3 Part 1',
#     'release_date': '2020-04-17',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0prxUuXzlIyjSJU9ej003n'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#      'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#      'id': '58r1rB5t3VF5X6yXGPequV',
#      'name': 'Maverick City Music',
#      'type': 'artist',
#      'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nO7Yt0Jon48sqKR6VME4T'},
#      'href': 'https://api.spotify.com/v1/artists/5nO7Yt0Jon48sqKR6VME4T',
#      'id': '5nO7Yt0Jon48sqKR6VME4T',
#      'name': 'Joe L Barnes',
#      'type': 'artist',
#      'uri': 'spotify:artist:5nO7Yt0Jon48sqKR6VME4T'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rc8nzClXj7sUjvsHVg6AD'},
#      'href': 'https://api.spotify.com/v1/artists/4rc8nzClXj7sUjvsHVg6AD',
#      'id': '4rc8nzClXj7sUjvsHVg6AD',
#      'name': 'Naomi Raine',
#      'type': 'artist',
#      'uri': 'spotify:artist:4rc8nzClXj7sUjvsHVg6AD'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 646239,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCAET2042835'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0aZFEiDKLK2B4gzPaGCZVm'},
#    'href': 'https://api.spotify.com/v1/tracks/0aZFEiDKLK2B4gzPaGCZVm',
#    'id': '0aZFEiDKLK2B4gzPaGCZVm',
#    'is_local': False,
#    'name': 'Promises',
#    'popularity': 66,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:0aZFEiDKLK2B4gzPaGCZVm'},
#   'video_thumbnail': {'url': None}}]

# %%
len(results)
# Out:
# 4

# %%
uris = []
names = []

for result in results:
    for i in result["items"]:
        uris.append(i["track"]["uri"])
        names.append(i["track"]["name"])

# %%
uris
# Out:
# ['spotify:track:5Tnx4R7Gwj1LZsfssfzchh',
#  'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ',
#  'spotify:track:0R3OcHrzq3f8raukyZgTAc',
#  'spotify:track:24upABZ8A0sAepfu91sEYr',
#  'spotify:track:7IBrKDuBlyz3vW9JFCux10',
#  'spotify:track:3ecVMxkn0sJ3nlx1uS0IVN',
#  'spotify:track:6NF8MZ2trxckVBr82pyyPt',
#  'spotify:track:6FwkZ5lYdCUh1mzI1Bhojn',
#  'spotify:track:75QdM3nsnAluOD19G1J4il',
#  'spotify:track:6Yg3gGtLuZTyZ8i4zGUaJa',
#  'spotify:track:03XkLBYaV5PlgHQYlTEvZm',
#  'spotify:track:6f3Slt0GbA2bPZlz0aIFXN',
#  'spotify:track:7uSdpAkxgB0948bW7yjjJO',
#  'spotify:track:5nC2BQzszGGkZi7cvxFzH4',
#  'spotify:track:6GRDI9suQHikFP6euIXnpq',
#  'spotify:track:0aZFEiDKLK2B4gzPaGCZVm',
#  'spotify:track:5MpayeDmtJwgCpxQOkVBtN',
#  'spotify:track:3jQa7pofP3CHRTt4Xnoyt6',
#  'spotify:track:1SIdietqp8lUZGyeGACpxj',
#  'spotify:track:7g5m83brkyQ3tYXxomx6P2',
#  'spotify:track:51Fi8flrG3IHrFeU4G198k',
#  'spotify:track:6f2QFiiM5mePNlUeHUL3Hh',
#  'spotify:track:2p6qtCgJz42Mae5p4zUwDl',
#  'spotify:track:4pCCSIQzxFsFPakL9LyUbc',
#  'spotify:track:3Xi4Hu8BcUNdUBmBjpkh20',
#  'spotify:track:5dBHELm9dGc3kKsPeYIYKd',
#  'spotify:track:0BrFvLsC8ydsHIz6jghMPo',
#  'spotify:track:2ItBFk9uQHqPyANx8rEUr2',
#  'spotify:track:3LQxLAwCQ7gqzTgiL8oRrh',
#  'spotify:track:7iPfY3lXOMH77BoZstQUhc',
#  'spotify:track:6HnbvDYhRA5E1fItsYnbPQ',
#  'spotify:track:6APIeDnJBcgEFOWv5plRhD',
#  'spotify:track:4YCSXeEYWw1aIF3aNSzl6j',
#  'spotify:track:2VeWXYKHiESWNipFu33QGv',
#  'spotify:track:3BF0S0f1KQNvTd5c9B3E2u',
#  'spotify:track:0LnppLKOrMMbhhauZBBJcQ',
#  'spotify:track:36wB70EUpiU89GF2eLWjfD',
#  'spotify:track:1tj2z0tht71UmMqRqgmH2K',
#  'spotify:track:5X6bt0reZfHUAn0KpBrArf',
#  'spotify:track:5N66DdC8iiowzoR6CDrAii',
#  'spotify:track:5Adxsld8lL9MLcaULeoSKu',
#  'spotify:track:4OlcB3a0LJIrltfQt8vV1S',
#  'spotify:track:5dOnBq60AajXJ9MtOG64FN',
#  'spotify:track:3GW78c0NinQpL8HtzU9X13',
#  'spotify:track:0BcbSvjOZ9dUDmXAcnqmeO',
#  'spotify:track:0niy8sCXnQXc9JZGWWVvLd',
#  'spotify:track:2P9GzQDc9rFeJ0TwY3ewRP',
#  'spotify:track:4QrUtdSJNxBZ11BU0sPa7J',
#  'spotify:track:3d3wW0qalzZdZbFbtSfRWt',
#  'spotify:track:36soyVMvHB2FRb0DgLr9ll',
#  'spotify:track:2Cn9pJmdrntPhYCr9ym5KF',
#  'spotify:track:6s4xgBaxucbNcyVsFmMClO',
#  'spotify:track:7mUR9hqvGLG5XicfVl7gTm',
#  'spotify:track:5hJVLQbPigabZDgZhulWVD',
#  'spotify:track:6kscmCdqAfXzADEXf0VueN',
#  'spotify:track:2gZ0GfJ2aVO7qptKCohWwp',
#  'spotify:track:5AVxVsEjJM144w91gKRdq1',
#  'spotify:track:4L2D6eUEQOdvAyjc0khFAW',
#  'spotify:track:0xlT8eSY5eLdy4S3eyWtNp',
#  'spotify:track:3bnsBfPcpsCT60fs7R2M02',
#  'spotify:track:2nDoc1hwGcNKf8QWCVCeLG',
#  'spotify:track:6oklNuDesCz9yjI2mZdv4B',
#  'spotify:track:6lXC8iSvGz65ZwoZXYKGtj',
#  'spotify:track:50GwMEDGgD1AVVcYXOuAnl',
#  'spotify:track:24aGazQ1aZwIW4B4b98Kr3',
#  'spotify:track:4P0YbSLRJEXvDExPcioMLc',
#  'spotify:track:4z6MjoY4K07vqeI4023U2Q',
#  'spotify:track:3HoO8VUfyXwkgqwaIrVM7u',
#  'spotify:track:6Dkjc0jzDgNtHf6Kr0HTLf',
#  'spotify:track:48qAOahd28j6zuPAWSLZ4K',
#  'spotify:track:4GiHrGKNP80LnTO4xDTX1A',
#  'spotify:track:1uGoNcJCeOz4Y3DHodcjSk',
#  'spotify:track:5QGhn5Z7RRsMKx6hPFOSUO',
#  'spotify:track:2yTjLx8CDh1kpfl9L4XBmI',
#  'spotify:track:0PoKop2ivdajRtzpXbKuyS',
#  'spotify:track:6kfCqm1AIN0zFipPemEbtG',
#  'spotify:track:66ai6JEub08B31JWtBghr6',
#  'spotify:track:30ltN7cC2P6pCueI7aVcxO',
#  'spotify:track:4Z9NjZthRYiY4pjcScpWsc',
#  'spotify:track:4QbU6tZQnsDtyEm35ikBZq',
#  'spotify:track:2nI7rOSYklk4SZ3ccPvG2j',
#  'spotify:track:6xBpeJHE26gAAjgVkCBbzU',
#  'spotify:track:4uxvvTbmuTKJky7w2LVXTW',
#  'spotify:track:7bzE1Y56OWShf2970pBfYM',
#  'spotify:track:56S04BxQD4FsePfNQIt6Cd',
#  'spotify:track:6bnDla4VOr2JBtyK3AeZEJ',
#  'spotify:track:6Esdz6FtuGJaQuJ6rLIUil',
#  'spotify:track:1NY7BwYlCryUbEyXrImFKM',
#  'spotify:track:4c3RWR07IbbOs0FP7Ei6Hd',
#  'spotify:track:3U8Fx7zNTQrctytkj6Gqgd',
#  'spotify:track:1L4NadMj3Jj7YgGaikyhfr',
#  'spotify:track:5xbuJuQsTVheVZvX2AJVIv',
#  'spotify:track:6YDgMoJ8ssOuKjQ6jiz4Kk',
#  'spotify:track:4tKmydUDl8OIeb7fioEsnl',
#  'spotify:track:28XMNc5If5BmJWYDU42gkw',
#  'spotify:track:2d6ml9Qkx8r4EjuUyrdpRV',
#  'spotify:track:1eqyKmkcp7b2s1PU9fEZRS',
#  'spotify:track:3weNRklVDqb4Rr5MhKBR3D',
#  'spotify:track:7N2tmiKcG2bUgZkuRKXor4',
#  'spotify:track:6mfmrVSe5Cm7cvsNwW6uJk',
#  'spotify:track:64LTn5fTsPR0QLy7bVYl9w',
#  'spotify:track:1BncfTJAWxrsxyT9culBrj',
#  'spotify:track:0kckvKwPBjQuVLgwGnICAv',
#  'spotify:track:0U69ZvJfshKs1OVIyW1E7B',
#  'spotify:track:0H2VhGUC3P3hvwz8rdGIpC',
#  'spotify:track:5qVqMPQdfFywNQIOP7Ncdz',
#  'spotify:track:1mlLOJXeUrwviYpUHYeZE8',
#  'spotify:track:0OrZXWjGgGUuoIoqnLvtJN',
#  'spotify:track:3QPPP2YozZ5xmMmpDB3c9n',
#  'spotify:track:1GBUqmdRjScFoG0cs8jEGZ',
#  'spotify:track:4XJXYvjW0CB2MLMk8l7Vdi',
#  'spotify:track:5xm20JNLHy9vUVrnmZS6Uj',
#  'spotify:track:7KrdT8Zk0WGeyNtaCwQR08',
#  'spotify:track:6MgSw0gPRiCeYid2y2BgWS',
#  'spotify:track:1seJCRhM5PqQ5xGebh0iQ0',
#  'spotify:track:1GCpKbwGqAwleD1GK31zT0',
#  'spotify:track:1nPHuiD55BwCjJeUBxDsHd',
#  'spotify:track:41g83Usxjh9TRoxNGGqTTU',
#  'spotify:track:687dYpD7d1LTkxSA4H1Qzd',
#  'spotify:track:0T5p4InF1JeJBYHVU5xvJz',
#  'spotify:track:67XXdBK80hV7APXgWwb3jg',
#  'spotify:track:670kHoKB4WnZCVSJz4ymNx',
#  'spotify:track:7rIWt3zlh2ntF1XDzj3wee',
#  'spotify:track:2XRnbXXt4vdrPdI3QL8Lym',
#  'spotify:track:7lY6qt63y0Ag5lpHMVglLo',
#  'spotify:track:4v3o4IJt1VRDNiM2LCoOXV',
#  'spotify:track:5xVcnhVL0AwcOgbpuxTu6W',
#  'spotify:track:4QfYHdV8hMoyS9qKUct98q',
#  'spotify:track:1hX3yoGAJypm6dMMWLoyKo',
#  'spotify:track:5sztos7ZCFp6Qmk8WvEMZH',
#  'spotify:track:4nd6FMCfNFWkbi2dnsf5I3',
#  'spotify:track:6SAZljHhCrFcqtVe1AQ0ED',
#  'spotify:track:6yjpji2Jlie9S2zBm2GZwE',
#  'spotify:track:3NrOSg735np3PW8OEvt5F8',
#  'spotify:track:5CBzaWVsJgl4DD1oNInz9b',
#  'spotify:track:7zv2BCCUu8bwd9fo9BA8IK',
#  'spotify:track:7cp3lHAPGcUbb7tJP0kuxl',
#  'spotify:track:4Lpe7VxL34rcMnpfOwoqOI',
#  'spotify:track:02xd7yuAEiLOF7rt4zlPep',
#  'spotify:track:58vWVeAtv2LKwlYyRLPWV5',
#  'spotify:track:5wDBBKEIiDYwPQj4SpbBPI',
#  'spotify:track:31BLOz0XDJPPDKI94Gd14v',
#  'spotify:track:1gK2cDl2dY7DFUEXvoMms6',
#  'spotify:track:3vSOD8Ng5m8eLH4EhoJcTL',
#  'spotify:track:33DWEcHqtj1w5rnghLE77x',
#  'spotify:track:4CBIdJ5o1XyMlkUg4jOHWg',
#  'spotify:track:7i9cdG6l1lg0xAraTublsw',
#  'spotify:track:65J9Ep6oWjSgyJ8MFChjWl',
#  'spotify:track:6Ntsj2X8cjYHoG9ykImLsT',
#  'spotify:track:5RWA30VaTsYkFrkzxKL3aK',
#  'spotify:track:1YluEbLfaWBfV2GpQQLOcZ',
#  'spotify:track:5Gm2tHCFTzb0vHZfReSr5f',
#  'spotify:track:0EnEULk14Oso59QtQHVUoC',
#  'spotify:track:2XYEu7Deyz20WeL6Py3XLc',
#  'spotify:track:1fWeZQfdmAoi3HWpHcn4tM',
#  'spotify:track:4cfwFc5ptXuzQMT9fSdnOl',
#  'spotify:track:4DsbdOinvRPoD2ax4DhxMU',
#  'spotify:track:2kAdK72mjmKiAxfAMGgXBU',
#  'spotify:track:0d71p8tQDxLgdTkEHcxQyl',
#  'spotify:track:4i8ly7ffzWu8nfKLI8SZFj',
#  'spotify:track:3z3nJD2LEW3yFMaEjjGerZ',
#  'spotify:track:2ZrF3UfwS50CKE8jQQVjWj',
#  'spotify:track:5zIJsFst05gsrUdr9ghEpG',
#  'spotify:track:4PRnYCH5hoxypKVcOBvx3a',
#  'spotify:track:4ju98rvX917EwXLKLnRbQ2',
#  'spotify:track:6q5co1XdRmnMeWlL1RWXPK',
#  'spotify:track:29T3H5d9TgTlYcKiuNxdRT',
#  'spotify:track:5RqKo9P4DLA0bVyY70cWkr',
#  'spotify:track:43bSKCMWHIuBsUVmQcDX1J',
#  'spotify:track:2Lio4KTzsA8BPLhXmyo4CQ',
#  'spotify:track:4xqay5NL9jPHSCP2mo3U67',
#  'spotify:track:6aANvQTjMgtOlCAaHlYcyn',
#  'spotify:track:0Y9BzZGT2FuLVPrHoq1g2G',
#  'spotify:track:419qlOGNXoyICx4jO0hqaj',
#  'spotify:track:3hCPh4oVVjaM8tv9sFH8cx',
#  'spotify:track:2xU2c2aqQDSHgNGHcQnOj4',
#  'spotify:track:0vzSIBAqnN1HzvWrPbh6VF',
#  'spotify:track:3iWo5Y9DpJNdFI3lERYgEy',
#  'spotify:track:0ftAOThcYwpSDapJhDOy7o',
#  'spotify:track:6Olyr6tQ7DKWPJro6nn35C',
#  'spotify:track:5BRfucuiAf5IYRbwBYBYPZ',
#  'spotify:track:3hgRiVuiBWVbpd4kBQD68m',
#  'spotify:track:6t7lMFHSifu9j8NPMNCv9T',
#  'spotify:track:3lLKvUcryMjlY35OizFKJb',
#  'spotify:track:5xlRxcBGa6RqPRBzKP8fwv',
#  'spotify:track:16xQMSrDSEWP5Lp8GrHGcu',
#  'spotify:track:46tPGzCXCI2oKsemztDA9u',
#  'spotify:track:7pgJTa3eZM4kkT2vsZUmFt',
#  'spotify:track:1k82bzEjGy47GX0EbVPseH',
#  'spotify:track:1BKT2I9x4RGKaKqW4up34s',
#  'spotify:track:7m97yKVzPpXV9Z4ezEziOD',
#  'spotify:track:3WXNzlFDSfjEmNFUOSccf7',
#  'spotify:track:2ImuQo1g14CTR9hZAZD3aQ',
#  'spotify:track:4Qxv2L4JICAWLFrBV6QeH8',
#  'spotify:track:740gNyGWKk98gy8nJLhHrv',
#  'spotify:track:6jaj4k0LwFLy1q54TXZZpZ',
#  'spotify:track:3IrkbGQCoEPAkzJ0Tkv8nm',
#  'spotify:track:7rxeH2yGlCeDKEkNNTpY29',
#  'spotify:track:2TZuNkLb0J6oKLEdlZ0XX3',
#  'spotify:track:17GdAx0kHOFNXZiCj8HuOW',
#  'spotify:track:0ySoJyAbKGLI5yShGBOIQ8',
#  'spotify:track:7nYvUtkQMx1v80S2FH2s9J',
#  'spotify:track:3KKrZ3adgWcJiJQWFqoDnv',
#  'spotify:track:6SuIF8oh96UPJIIJjKvtIe',
#  'spotify:track:6VqQjCxM21kapF2RxdTtYA',
#  'spotify:track:0s46SltT4On0Z6kglK1I5c',
#  'spotify:track:0W2mz7mvaBaEsC4rmoRNPn',
#  'spotify:track:350tsRjB2hVodX7wjCMHcS',
#  'spotify:track:38XOEv37waF4pd8Ztmna7K',
#  'spotify:track:67mtN6BlsJR0LVyzvNZnGt',
#  'spotify:track:6aJ90LBl96bly9zuEH1U2X',
#  'spotify:track:2nCVH8UkoII2jWwx6SYVso',
#  'spotify:track:3F3R4uyTMkX9jRCEVVmdz6',
#  'spotify:track:0LWkaEyQRkF0XAms8Bg1fC',
#  'spotify:track:4EIzsbsVOzfLwyIvfsRQ8H',
#  'spotify:track:0Mu1MYdE414HeybYSms5KK',
#  'spotify:track:71A6V5dh5Y8ikhm6NGwZ7p',
#  'spotify:track:0f1yzIIGD8k32DNVeEn6jb',
#  'spotify:track:3eY9pixHny3kVRLeqNezQx',
#  'spotify:track:1FkgoPdajl8gwC1hlyvHtC',
#  'spotify:track:4WMBl2wiGUSGa5C7tfQEAo',
#  'spotify:track:3G0z1kH46uVRqW7f9Qp1OR',
#  'spotify:track:3gKwVWwKmeuFtPubICbOGc',
#  'spotify:track:6Ag4SYLUGFdnJrCwUIb4mT',
#  'spotify:track:3cb6gJ7SHYuZ3NVm996ffD',
#  'spotify:track:1zONdCQrEJ4t3mlzKQADEN',
#  'spotify:track:0hbSQvosqCvCFaiSRPEUYP',
#  'spotify:track:28AvvchUP85ihRe9xCzcfB',
#  'spotify:track:6C7ZgThn6Yan5MTZdAEEFw',
#  'spotify:track:7Afjy65bIVBMpFwCLTiuEe',
#  'spotify:track:10EGxvr4fSE42ABWZeJ3K3',
#  'spotify:track:2tY1gxCKslfXLFpFofYmJQ',
#  'spotify:track:0ZHu7jkSSrT0eK4OxuG4O5',
#  'spotify:track:4F4neui0edP1ozygvFiCi7',
#  'spotify:track:5JV45IebgbfO3EylYV49rl',
#  'spotify:track:7aRGb3vZGMLNpK2PEdUjdA',
#  'spotify:track:5Tl0HJvynZtKdSUMKbFVVX',
#  'spotify:track:1xZdjsAGrY4BUIbIlYy3EX',
#  'spotify:track:2qfTGzETefwtBWKDThZjnU']

# %%
audio_feat = []

for uri in uris:
    audio_feat.extend(sp.audio_features(uri))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-971fac2da2ab> in <module>
#       2
#       3 for uri in uris:
# ----> 4     audio_feat.extend(sp.audio_features(uri))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/client.py in audio_features(self, tracks)
#    1672         if isinstance(tracks, str):
#    1673             trackid = self._get_id("track", tracks)
# -> 1674             results = self._get("audio-features/?ids=" + trackid)
#    1675         else:
#    1676             tlist = [self._get_id("track", t) for t in tracks]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     238
#     239         try:
# --> 240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
#     242                 timeout=self.requests_timeout, **args
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
audiofeat_df = pd.DataFrame(audio_feat)

# %%
audiofeat_df["name"] = names

# %%
cols = audiofeat_df.columns.to_list()

# %%
cols = cols[-1:] + cols[:-1]

# %%
audiofeat_df = audiofeat_df[cols]
audiofeat_df.head()
# Out:
#                                      name  danceability  energy  key  \
# 0  You're the One - From "I Lost My Body"         0.535   0.724    5
# 1                               The Alien         0.464   0.334    6
# 2             Oh, Pecador (Oh, Sinne Man)         0.623   0.239   11
# 3                 Moon (And It Went Like)         0.662   0.657    7
# 4                         Never Come Back         0.776   0.684    5
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -9.905     1       0.0618         0.202          0.901000    0.0983
# 1   -12.916     1       0.0313         0.307          0.247000    0.1100
# 2   -12.638     0       0.0979         0.886          0.000929    0.1710
# 3   -10.002     1       0.0345         0.288          0.856000    0.1020
# 4    -8.934     1       0.0367         0.405          0.559000    0.0663
#
#    valence    tempo            type                      id  \
# 0   0.3700  159.948  audio_features  5Tnx4R7Gwj1LZsfssfzchh
# 1   0.3260  165.278  audio_features  5eKfpH2dQ7FltCqb7LWEGJ
# 2   0.5850  124.485  audio_features  0R3OcHrzq3f8raukyZgTAc
# 3   0.0584  117.986  audio_features  24upABZ8A0sAepfu91sEYr
# 4   0.6550  127.979  audio_features  7IBrKDuBlyz3vW9JFCux10
#
#                                     uri  \
# 0  spotify:track:5Tnx4R7Gwj1LZsfssfzchh
# 1  spotify:track:5eKfpH2dQ7FltCqb7LWEGJ
# 2  spotify:track:0R3OcHrzq3f8raukyZgTAc
# 3  spotify:track:24upABZ8A0sAepfu91sEYr
# 4  spotify:track:7IBrKDuBlyz3vW9JFCux10
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1L...
# 1  https://api.spotify.com/v1/tracks/5eKfpH2dQ7Fl...
# 2  https://api.spotify.com/v1/tracks/0R3OcHrzq3f8...
# 3  https://api.spotify.com/v1/tracks/24upABZ8A0sA...
# 4  https://api.spotify.com/v1/tracks/7IBrKDuBlyz3...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5Tnx...       167987
# 1  https://api.spotify.com/v1/audio-analysis/5eKf...       328933
# 2  https://api.spotify.com/v1/audio-analysis/0R3O...       145773
# 3  https://api.spotify.com/v1/audio-analysis/24up...       390639
# 4  https://api.spotify.com/v1/audio-analysis/7IBr...       305480
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
