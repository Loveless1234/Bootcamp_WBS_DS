# %% [markdown]
# ## Sending requests
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")

# %%
resp_json = response.json()

# %%
resp_json[:5]
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(resp_json).head()
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
requests.get("https://api.github.com/zen").text
# Out:
# 'Half measures are as bad as nothing at all.'

# %%
response = requests.get('https://api.github.com/events')

# %%
# get the .json from the response
github_response = response.json()

# %%
github_response[0]
# Out:
# {'id': '19023179118',
#  'type': 'PushEvent',
#  'actor': {'id': 36146783,
#   'login': 'Wanna-be-Coder',
#   'display_login': 'Wanna-be-Coder',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Wanna-be-Coder',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/36146783?'},
#  'repo': {'id': 415634396,
#   'name': 'Wanna-be-Coder/MIANS',
#   'url': 'https://api.github.com/repos/Wanna-be-Coder/MIANS'},
#  'payload': {'push_id': 8457498228,
#   'size': 1,
#   'distinct_size': 1,
#   'ref': 'refs/heads/gh-pages',
#   'head': 'b77ce75b1f8a65d5bceae59ec2097805f6ccc043',
#   'before': '2cfd3b174162b120af4c6c3a250e6391e4487319',
#   'commits': [{'sha': 'b77ce75b1f8a65d5bceae59ec2097805f6ccc043',
#     'author': {'email': '36146783+Wanna-be-Coder@users.noreply.github.com',
#      'name': 'Samin Sharar'},
#     'message': 'Create CNAME',
#     'distinct': True,
#     'url': 'https://api.github.com/repos/Wanna-be-Coder/MIANS/commits/b77ce75b1f8a65d5bceae59ec2097805f6ccc043'}]},
#  'public': True,
#  'created_at': '2021-11-23T22:14:56Z'}

# %%
from IPython.display import JSON
JSON(response.json()[:5])

# %%
len(github_response)
# Out:
# 30

# %%
#login
github_response[3]["actor"]["login"]
# Out:
# 'cata0309'

# %% [markdown]
# ### Exercise:
#
# Extract the "login", the repo name and the event type for each event.

# %%
login = []
repo = []
event_type = []

for i in range(len(github_response)):
    login.append(github_response[i]["actor"]["login"])
    
for i in range(len(github_response)):
    repo.append(github_response[i]["repo"]["name"])
    
for i in range(len(github_response)):
    event_type.append(github_response[i]["type"])

# %%
# turn it into a pandas dataframe
pd.DataFrame(github_response).head()
# Out:
#             id         type  \
# 0  19023179118    PushEvent
# 1  19023179126    PushEvent
# 2  19023179115    PushEvent
# 3  19023179131    ForkEvent
# 4  19023179097  MemberEvent
#
#                                                actor  \
# 0  {'id': 36146783, 'login': 'Wanna-be-Coder', 'd...
# 1  {'id': 35769108, 'login': 'S1nd5', 'display_lo...
# 2  {'id': 59850346, 'login': 'p-han-tom', 'displa...
# 3  {'id': 35623921, 'login': 'cata0309', 'display...
# 4  {'id': 33396785, 'login': 'saralavanchy', 'dis...
#
#                                                 repo  \
# 0  {'id': 415634396, 'name': 'Wanna-be-Coder/MIAN...
# 1  {'id': 422141598, 'name': 'S1nd5/surveyplatfor...
# 2  {'id': 423229696, 'name': 'EddieZhang540/BadLe...
# 3  {'id': 324501076, 'name': 'rootVIII/topui', 'u...
# 4  {'id': 429911876, 'name': 'alkemyTech/OT105-Cl...
#
#                                              payload  public  \
# 0  {'push_id': 8457498228, 'size': 1, 'distinct_s...    True
# 1  {'push_id': 8457498243, 'size': 1, 'distinct_s...    True
# 2  {'push_id': 8457498233, 'size': 1, 'distinct_s...    True
# 3  {'forkee': {'id': 431269317, 'node_id': 'R_kgD...    True
# 4  {'member': {'login': 'pdvallejos', 'id': 82845...    True
#
#              created_at                                                org
# 0  2021-11-23T22:14:56Z                                                NaN
# 1  2021-11-23T22:14:56Z                                                NaN
# 2  2021-11-23T22:14:56Z                                                NaN
# 3  2021-11-23T22:14:56Z                                                NaN
# 4  2021-11-23T22:14:56Z  {'id': 92044030, 'login': 'alkemyTech', 'grava...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(github_response).head()
# Out:
#             id         type  public            created_at  actor.id  \
# 0  19023179118    PushEvent    True  2021-11-23T22:14:56Z  36146783
# 1  19023179126    PushEvent    True  2021-11-23T22:14:56Z  35769108
# 2  19023179115    PushEvent    True  2021-11-23T22:14:56Z  59850346
# 3  19023179131    ForkEvent    True  2021-11-23T22:14:56Z  35623921
# 4  19023179097  MemberEvent    True  2021-11-23T22:14:56Z  33396785
#
#       actor.login actor.display_login actor.gravatar_id  \
# 0  Wanna-be-Coder      Wanna-be-Coder
# 1           S1nd5               S1nd5
# 2       p-han-tom           p-han-tom
# 3        cata0309            cata0309
# 4    saralavanchy        saralavanchy
#
#                                      actor.url  \
# 0  https://api.github.com/users/Wanna-be-Coder
# 1           https://api.github.com/users/S1nd5
# 2       https://api.github.com/users/p-han-tom
# 3        https://api.github.com/users/cata0309
# 4    https://api.github.com/users/saralavanchy
#
#                                     actor.avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/36146783?  ...
# 1  https://avatars.githubusercontent.com/u/35769108?  ...
# 2  https://avatars.githubusercontent.com/u/59850346?  ...
# 3  https://avatars.githubusercontent.com/u/35623921?  ...
# 4  https://avatars.githubusercontent.com/u/33396785?  ...
#
#    payload.pull_request.merged_by.gists_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.merged_by.starred_url  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   payload.pull_request.merged_by.subscriptions_url  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    payload.pull_request.merged_by.organizations_url  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    payload.pull_request.merged_by.repos_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    payload.pull_request.merged_by.events_url  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   payload.pull_request.merged_by.received_events_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   payload.pull_request.merged_by.type  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   payload.pull_request.merged_by.site_admin payload.issue.assignee
# 0                                       NaN                    NaN
# 1                                       NaN                    NaN
# 2                                       NaN                    NaN
# 3                                       NaN                    NaN
# 4                                       NaN                    NaN
#
# [5 rows x 634 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'timestamp': 1637706416,
#  'message': 'success',
#  'iss_position': {'longitude': '-1.5153', 'latitude': '45.7913'}}

# %% [markdown]
# ## Spotipy
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into an Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/app-settings/

# %% [markdown]
# #### Authentification
#
# Follow the wrapper for the API docs: https://spotipy.readthedocs.io/en/2.16.1/

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(
    client_credentials_manager=SpotifyClientCredentials(
    client_id="5b3311d52b2845cf9c3bf804ea93a3d2",
    client_secret="7cfe8f28ffbc4b66afe9ea86a10e5cbf"
    ))

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This function allows you to find songs with using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
JSON(results)

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: you know that because the dictionary is wrapped by square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features:

# %%
results["tracks"]["items"][0]["popularity"]
# Out:
# 81

# %% [markdown]
# This is how Spotify identifies individual songs: with an `uri`. (the `id` and the `url` are also ways to identify uniquely each song).

# %%
#results["tracks"]["items"][0]['name']

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chilli Peppers and store the `uri` of the songs and their names.

# %%
# send request and store the response
red_hot = sp.search(q="Red hot chili peppers", limit=10)

# initialize empty lists to store stuff later
list_of_uri = []
list_of_song_names = []

# iterate through the "items" (the songs), and append
# the "uri" and the "name" to the lists we created
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# print results
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS', 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx', 'spotify:track:1XxCiPw07rd1ytYnE7SoJI', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:4nRi0PlIpoy9SyySD1IDGY', 'spotify:track:2aibwv5hGXSgw7Yru8IYTO', 'spotify:track:4dzbGvxqQ1DsF6m6RUlPwg']
#
#
# ['Under the Bridge', 'Anthony Kiedis', 'Around the World', "Can't Stop", 'Buried Alive', "Road Trippin'", 'Californication', 'By the Way - Live', 'Snow (Hey Oh)', 'Pedigree']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results into a big list called `results`.

# %%
artists = ["Red hot chili peppers", "SCARR", "Whitney Houston"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
#results

# %% [markdown]
# We can iterate through the `results` list and get the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Anthony Kiedis',
#  'Around the World',
#  "Can't Stop",
#  'Buried Alive',
#  "Road Trippin'",
#  'Californication',
#  'By the Way - Live',
#  'Snow (Hey Oh)',
#  'Pedigree',
#  'Scarred From Love',
#  'Emotionally Scarred',
#  'SCARR',
#  'Scarred',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred Island',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred',
#  'Rolling Loud (feat. Big Scarr, BigWalkDog)',
#  'Free Smoke (feat. Big Scarr)',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'I Look to You',
#  'Higher Love',
#  'The Star Spangled Banner (feat. The Florida Orchestra) - Live from Super Bowl XXV',
#  'I Will Always Love You',
#  'Exhale (Shoop Shoop) - from "Waiting to Exhale" - Original Soundtrack',
#  'I Have Nothing',
#  'You Give Good Love',
#  'How Will I Know',
#  "Didn't We Almost Have It All"]

# %% [markdown]
# #### Exploring the tracks

# %%
# Get artist id's for all the tracks you found
query = "Despacito"

despacito = sp.search(q = query, limit = 50)

# %%
despacito_artists = set()

for item in despacito["tracks"]["items"]:
    for artist in item["artists"]:
        despacito_artists.add(artist["uri"])

# %%
despacito["tracks"]["items"][2]["artists"][0]["name"]
# Out:
# 'Luis Fonsi'

# %%
despacito_artists
# Out:
# {'spotify:artist:0NxhAEPOSeCg6vypFr7yjU',
#  'spotify:artist:0QNakySWugkMvfwbDoaY9L',
#  'spotify:artist:0fIdQWpwzU2oEtsoyArDOL',
#  'spotify:artist:0r3y7sISJoUIfT5E85AYII',
#  'spotify:artist:1NiC1V6xc8OR1ERiIoCvtx',
#  'spotify:artist:1Uz4WPsI4VylKT6lhJiDO5',
#  'spotify:artist:1emgbX82aLN8eCS3AnXFfC',
#  'spotify:artist:1mX1TWKpNxDSAH16LgDfiR',
#  'spotify:artist:1qwVM2JnEMXbKgvZESGsRn',
#  'spotify:artist:1rVo9h17cHhWerDiZj0yXH',
#  'spotify:artist:1sJhbiQRSIKZeTYEZfzBSV',
#  'spotify:artist:1uNFoZAHBGtllmzznpCI3s',
#  'spotify:artist:1uj8EOCKAXn4w2TR7CVnQb',
#  'spotify:artist:26AHtbjWKiwYzsoGoUZq53',
#  'spotify:artist:2T06whb4s6UiufL1j5Qtz9',
#  'spotify:artist:2VAjBQ6cM2faT2UKxONV93',
#  'spotify:artist:3YfvowVavHTzXLKmKaYM1c',
#  'spotify:artist:3YrM00mKs7wqOtBPmeSoEo',
#  'spotify:artist:3vOJJbGGUOtC9csissiL0G',
#  'spotify:artist:4KLOMib6zqzNayKwLWTs2Q',
#  'spotify:artist:4L5SLCIDWPPNGzrLraYCOS',
#  'spotify:artist:4N5fp4zhTsVITZTVfsXpc2',
#  'spotify:artist:4V8Sr092TqfHkfAA5fXXqG',
#  'spotify:artist:4VMYDCV2IEDYJArk749S6m',
#  'spotify:artist:4fdxbJLSNRIMkMGbLs5QPF',
#  'spotify:artist:4j4Lq1ut4h3H3eTIubtyog',
#  'spotify:artist:5DsbNI5ZIDIWjmsAdaYvZ2',
#  'spotify:artist:5HPu6u2rDA0f6jp51xZAEq',
#  'spotify:artist:5KWOCu1saEHAhPiLKlOLIy',
#  'spotify:artist:5tqJLLaSDpdhDAwqWgAdXM',
#  'spotify:artist:62rnGiDozQmBBk5yM21yOC',
#  'spotify:artist:6Fi8CHfO8WGtu3yO8c2Mc4',
#  'spotify:artist:6MERXsiRbur2oJZFgYRDKz',
#  'spotify:artist:6QtqvuYuaOJy4te3nfkHKK',
#  'spotify:artist:6RTlv2UCWtRggV0rIo5TrN',
#  'spotify:artist:6U3ybJ9UHNKEdsH7ktGBZ7',
#  'spotify:artist:6dBIk14xcZqU0cRsyjXNkX',
#  'spotify:artist:6mU8ucezzms5I2kNH6HNlu',
#  'spotify:artist:6wBOZ9D65AcqUlfKUqsQ7R',
#  'spotify:artist:72iuahEAHKaMzDXKVw6e8P',
#  'spotify:artist:738wLrAtLtCtFOLvQBXOXp',
#  'spotify:artist:7CQwac16i1W5ej8YpuL3dv',
#  'spotify:artist:7dTPvuNcEXLkQ1XiAuiWIP',
#  'spotify:artist:7p3ipw2PvGG0X2x6zL1DLO',
#  'spotify:artist:7y33enVLfDvft6HGNmcxdV'}

# %% [markdown]
# ### Playlists

# %%
my_playlist = sp.user_playlist_tracks(user="spotify",
                                      playlist_id="https://open.spotify.com/playlist/24T3swe0HN7JWLfsDcakHw?si=ce24270cef314a9a")

# %% [markdown]
# Extract all songs IDs from a playlist

# %%
my_playlist["items"][0]["track"]["uri"]
# Out:
# 'spotify:track:3v4HvdYsdAc8K9Fy5SdyGe'

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %%
sp.audio_features("spotify:track:3d9DChrdc6BOeFsbrZ3Is0")
# Out:
# [{'danceability': 0.559,
#   'energy': 0.345,
#   'key': 4,
#   'loudness': -13.496,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.0576,
#   'instrumentalness': 0.000105,
#   'liveness': 0.141,
#   'valence': 0.458,
#   'tempo': 84.581,
#   'type': 'audio_features',
#   'id': '3d9DChrdc6BOeFsbrZ3Is0',
#   'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0',
#   'track_href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d9DChrdc6BOeFsbrZ3Is0',
#   'duration_ms': 264307,
#   'time_signature': 4}]

# %% [markdown]
# ### Exercise: Create a function that takes a song name and returns its audio features

# %%
#function building
def get_audio_feat_song(song_name):
    result = sp.search(q=song_name, limit=1)
    uri = result["tracks"]["items"][0]["uri"]
    return sp.audio_features(uri)

# %%
get_audio_feat_song("Sailing to Philadelphia")
# Out:
# [{'danceability': 0.589,
#   'energy': 0.484,
#   'key': 6,
#   'loudness': -10.126,
#   'mode': 0,
#   'speechiness': 0.0249,
#   'acousticness': 0.641,
#   'instrumentalness': 0.107,
#   'liveness': 0.0873,
#   'valence': 0.149,
#   'tempo': 99.067,
#   'type': 'audio_features',
#   'id': '4eA4i2Uf0DDIkpyesj98Ag',
#   'uri': 'spotify:track:4eA4i2Uf0DDIkpyesj98Ag',
#   'track_href': 'https://api.spotify.com/v1/tracks/4eA4i2Uf0DDIkpyesj98Ag',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eA4i2Uf0DDIkpyesj98Ag',
#   'duration_ms': 353120,
#   'time_signature': 4}]

# %%
result.keys()
# Out:
# dict_keys(['tracks'])

# %%
result["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:2tUBqZG2AbRi7Q0BIrVrEj'

# %% [markdown]
# ### Exercise: Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have ot be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Now collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %%
playlists = ["https://open.spotify.com/playlist/0ce6Rmxf7QXroqa1wzjWY8?si=05b8e416dedd4894",
             "https://open.spotify.com/playlist/2PjVPkj4a9kBvQIXaZ6UUt?si=c83fe4d8a4974095",
             "https://open.spotify.com/playlist/1h0CEZCm6IbFTbxThn6Xcs?si=549db4d4f4ca4c18",
             "https://open.spotify.com/playlist/37i9dQZF1DX7Mq3mO5SSDc?si=55c443251302424e",
             "https://open.spotify.com/playlist/6F8gakd4R9pm3iLxuzerEq"
            ]

# %%
results = []

for p in playlists:
    results.append(sp.playlist_tracks(p))

# %%
#results[0]["items"]

# %%
len(results)
# Out:
# 5

# %%
uris = []
names = []

for result in results:
    for i in result["items"]:
        uris.append(i["track"]["uri"])
        names.append(i["track"]["name"])

# %%
uris
# Out:
# ['spotify:track:5Tnx4R7Gwj1LZsfssfzchh',
#  'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ',
#  'spotify:track:0R3OcHrzq3f8raukyZgTAc',
#  'spotify:track:24upABZ8A0sAepfu91sEYr',
#  'spotify:track:7IBrKDuBlyz3vW9JFCux10',
#  'spotify:track:6jIf51que2Wcfoc2Ydc7Q2',
#  'spotify:track:1vlLZ0Sz4EyH8PxAEppGg0',
#  'spotify:track:2zcavp2fbc2jA8RxFNG5tq',
#  'spotify:track:3fF5NDC1ItEDJhDf7MZQ98',
#  'spotify:track:5RLGXFWKn60jaIM6yx1HQ5',
#  'spotify:track:5wLwV8xSTkPIgPfyiXEoNt']

# %%
audio_feat = []

for uri in uris:
    audio_feat.extend(sp.audio_features(uri))

# %%
audiofeat_df = pd.DataFrame(audio_feat)

# %%
audiofeat_df["name"] = names

# %%
cols = audiofeat_df.columns.to_list()

# %%
cols = cols[-1:] + cols[:-1]

# %%
audiofeat_df = audiofeat_df[cols]
audiofeat_df.tail(50)
# Out:
#                                    name  danceability  energy  key  loudness  \
# 289                   Surke Thaili Khai         0.692   0.751   10    -4.004
# 290                  Waiyaat Love Story         0.702   0.476    7    -7.907
# 291                        Dashain Aayo         0.414   0.911   10    -2.562
# 292                    Nidharma Achhtya         0.316   0.678   10    -9.451
# 293                       Aaudaichhu Ma         0.740   0.753    0    -7.841
# 294                    Bhatkiyeko Aasha         0.543   0.610    1    -7.252
# 295                    Khulla Aakash Ma         0.482   0.527    7    -8.144
# 296  Khulla Aakash Ma - Reprise Version         0.529   0.585    7    -7.613
# 297                             Kina Ni         0.661   0.560    0    -7.086
# 298                   Marchhu Ki Kya Ho         0.696   0.825    2    -5.289
# 299                       Uff Yo Mausam         0.643   0.833    8    -7.180
# 300                               Oh Oh         0.670   0.878    1    -5.995
# 301                      Pahilo Prem Ko         0.579   0.698    5    -6.799
# 302                         Ko Hau Timi         0.442   0.413    2    -9.965
# 303                 Timro Roop Ko Ranga         0.768   0.800    7    -6.273
# 304                      Byroad Ko Bato         0.685   0.897   10    -4.072
# 305                          First Love         0.744   0.801    1    -7.488
# 306                       Jaba Chalchha         0.720   0.744    5    -7.686
# 307                     Makhamali Mayaa         0.617   0.539    0   -10.155
# 308           Samjhana Birsana Salalala         0.594   0.282    5   -13.285
# 309              Ko Bhanchha Jeendagani         0.807   0.536   10    -8.337
# 310                Aaja Hamro Bhetbhako         0.736   0.438    8    -9.713
# 311    Chhori Malai Bhagi Bhagi Nasatau         0.457   0.555    6    -7.068
# 312                  DUI Dinko Jeendagi         0.602   0.445    7    -9.829
# 313           Aaja Sarai Ramri Dekhchhu         0.650   0.375    7    -9.846
# 314                      Shanibarko Din         0.711   0.456    7   -10.840
# 315                       Bandha Mayale         0.558   0.408   11    -8.521
# 316                         Eak Chhaina         0.728   0.680    7    -7.767
# 317                     Hami Tin Trikat         0.495   0.813    7    -4.702
# 318                     Sannani Hansana         0.480   0.690    5    -5.200
# 319                           Timi Mero         0.742   0.543    2    -9.330
# 320                  Timilai Dekhedekhi         0.400   0.506    7    -8.559
# 321                     Yo Mayale Launa         0.481   0.620    4    -8.808
# 322                  Ankha Ankha Boleni         0.532   0.626   11    -3.927
# 323                    Dherai Din Bhayo         0.594   0.784    4    -4.368
# 323     1       0.0441       0.48700          0.000006    0.0869    0.836
# 324     1       0.0460       0.08380          0.000002    0.0753    0.688
# 325     0       0.0552       0.62000          0.000055    0.0891    0.873
# 326     1       0.0378       0.42900          0.000111    0.1530    0.601
# 327     1       0.0243       0.22500          0.000002    0.1590    0.379
# 328     1       0.0553       0.82800          0.000006    0.6380    0.952
# 329     0       0.1330       0.72500          0.002130    0.7660    0.950
# 330     1       0.0431       0.12800          0.000013    0.1290    0.562
# 331     1       0.1930       0.19500          0.000003    0.1660    0.258
# 332     1       0.0349       0.64500          0.000068    0.0978    0.241
# 333     1       0.0723       0.67700          0.000000    0.0985    0.753
# 334     0       0.0452       0.46400          0.000000    0.1330    0.661
# 335     1       0.2920       0.50000          0.000005    0.0412    0.546
# 336     0       0.0350       0.55200          0.000000    0.1610    0.774
# 337     1       0.0346       0.75400          0.000020    0.5560    0.801
# 338     1       0.0315       0.51800          0.000255    0.2740    0.622
#
#        tempo            type                      id  \
# 289   88.981  audio_features  3AGv2QUobr8HG2gx7g5wQk
# 290   76.025  audio_features  4SPYSOCKjbNtypTE5lrZ8V
# 291  150.306  audio_features  0564PAe6filHYUdLUZQx20
# 292   70.982  audio_features  0hRNITYJlzqXQ6JwShdf8X
# 293  119.902  audio_features  4dmRDpT1AnD3K2dbIN32fY
# 294   77.963  audio_features  7Kp3GGTrXCHZC4KIE155K3
# 295  150.107  audio_features  4L4jSQSvsiyI6FHfCPBnUl
# 296   75.110  audio_features  3n3YufvjOcWOIpObJQGEkG
# 297  139.850  audio_features  3IZAcDriHGLrbpAxBTQZrh
# 298  111.962  audio_features  0gHCAqRH8kenvX2T0fyZbp
# 299  139.971  audio_features  491hjuW7LQ1qgGndbGg561
# 300  128.012  audio_features  6U8vHWTaA6xSB2uK8wCUdS
# 301   82.049  audio_features  2apzk8vtqGyOoFu6HfcdLs
# 302  171.982  audio_features  67z26v7S4huai7HvPdF694
# 303  123.081  audio_features  0rRr78TVjptoNbcQW1DAR7
# 304  132.003  audio_features  7vZlIVuCvDzwrAmz1YYhAD
# 305  113.019  audio_features  1fltI0adkC78Sel5tfuX6q
# 306  123.020  audio_features  5TUn5tl19ZMSTQ8ZDgCcFt
# 307   87.997  audio_features  1v9IeqGO9HFQB8TW6nnOgg
# 308  177.055  audio_features  7ww5zeqxfiPAPOIncvjIFi
# 309  131.992  audio_features  6xHna5L0jPugBCU0thICJW
# 310  104.037  audio_features  1DOp8uHcTRKoTHXIzRR1u4
# 311  176.292  audio_features  38V22n3ftRos2D1qgTwzyj
# 312  199.040  audio_features  1v8kKL2LTazvUC8N4bvui3
# 313   99.929  audio_features  76KFJR7JDtRHQ7tnG2GbaN
# 314   92.783  audio_features  65WPkLMModLGHg1Qkpsh3u
# 315   88.644  audio_features  5vgjzg0NBF4F0Q30HI3hHx
# 316  132.174  audio_features  7InhiO5tWrC3f6Bwabkck5
# 317  116.237  audio_features  26fmRduARwMWjemFqaL79t
# 318  153.070  audio_features  3h71urwqkBCbsG88dcr1fW
# 319  117.376  audio_features  2qbWok5i0LELY7jWsSl6MP
# 320  127.199  audio_features  0k2k4VBNf2jU6NbjC6H5uF
# 321   81.463  audio_features  1ikgb3HRXxWXgtWB5CASMF
# 322  160.073  audio_features  3LW34iMfotuySIqbx8IKGE
# 323   82.026  audio_features  6y174doEFq6b9YAoaQaNz7
# 324  158.080  audio_features  6KYOVZdNTFM4rRrx8JDe6e
# 325   79.964  audio_features  60aWoqTtmKZdvg2lfcb3Te
# 326  149.737  audio_features  308DhaYTyzrbkFj4qLpoN3
# 327   97.016  audio_features  4dsJS2Q8tkPtlhaOxbFwjg
# 328  195.029  audio_features  4LX54t9YXPriqVKiPFt95p
# 329  176.541  audio_features  44ayIwDeK4eGC16uMXXYPK
# 330  139.933  audio_features  1PHJnbEqGrHuiNuWJWiqCc
# 331   80.132  audio_features  19tvyPG8H7FqqBLePikeO4
# 332  129.917  audio_features  6znJFrlww4NtoQFHDXNdwu
# 333  122.601  audio_features  6jIf51que2Wcfoc2Ydc7Q2
# 334  148.167  audio_features  1vlLZ0Sz4EyH8PxAEppGg0
# 335  191.786  audio_features  2zcavp2fbc2jA8RxFNG5tq
# 336  105.994  audio_features  3fF5NDC1ItEDJhDf7MZQ98
# 337   87.485  audio_features  5RLGXFWKn60jaIM6yx1HQ5
# 338  137.019  audio_features  5wLwV8xSTkPIgPfyiXEoNt
#
#                                       uri  \
# 289  spotify:track:3AGv2QUobr8HG2gx7g5wQk
# 290  spotify:track:4SPYSOCKjbNtypTE5lrZ8V
# 291  spotify:track:0564PAe6filHYUdLUZQx20
# 292  spotify:track:0hRNITYJlzqXQ6JwShdf8X
# 293  spotify:track:4dmRDpT1AnD3K2dbIN32fY
# 294  spotify:track:7Kp3GGTrXCHZC4KIE155K3
# 295  spotify:track:4L4jSQSvsiyI6FHfCPBnUl
# 296  spotify:track:3n3YufvjOcWOIpObJQGEkG
# 297  spotify:track:3IZAcDriHGLrbpAxBTQZrh
# 298  spotify:track:0gHCAqRH8kenvX2T0fyZbp
# 299  spotify:track:491hjuW7LQ1qgGndbGg561
# 300  spotify:track:6U8vHWTaA6xSB2uK8wCUdS
# 301  spotify:track:2apzk8vtqGyOoFu6HfcdLs
# 302  spotify:track:67z26v7S4huai7HvPdF694
# 303  spotify:track:0rRr78TVjptoNbcQW1DAR7
# 304  spotify:track:7vZlIVuCvDzwrAmz1YYhAD
# 305  spotify:track:1fltI0adkC78Sel5tfuX6q
# 306  spotify:track:5TUn5tl19ZMSTQ8ZDgCcFt
# 307  spotify:track:1v9IeqGO9HFQB8TW6nnOgg
# 308  spotify:track:7ww5zeqxfiPAPOIncvjIFi
# 309  spotify:track:6xHna5L0jPugBCU0thICJW
# 310  spotify:track:1DOp8uHcTRKoTHXIzRR1u4
# 311  spotify:track:38V22n3ftRos2D1qgTwzyj
# 312  spotify:track:1v8kKL2LTazvUC8N4bvui3
# 313  spotify:track:76KFJR7JDtRHQ7tnG2GbaN
# 314  spotify:track:65WPkLMModLGHg1Qkpsh3u
# 315  spotify:track:5vgjzg0NBF4F0Q30HI3hHx
# 316  spotify:track:7InhiO5tWrC3f6Bwabkck5
# 317  spotify:track:26fmRduARwMWjemFqaL79t
# 318  spotify:track:3h71urwqkBCbsG88dcr1fW
# 319  spotify:track:2qbWok5i0LELY7jWsSl6MP
# 320  spotify:track:0k2k4VBNf2jU6NbjC6H5uF
# 321  spotify:track:1ikgb3HRXxWXgtWB5CASMF
# 322  spotify:track:3LW34iMfotuySIqbx8IKGE
# 323  spotify:track:6y174doEFq6b9YAoaQaNz7
# 324  spotify:track:6KYOVZdNTFM4rRrx8JDe6e
# 325  spotify:track:60aWoqTtmKZdvg2lfcb3Te
# 326  spotify:track:308DhaYTyzrbkFj4qLpoN3
# 327  spotify:track:4dsJS2Q8tkPtlhaOxbFwjg
# 328  spotify:track:4LX54t9YXPriqVKiPFt95p
# 329  spotify:track:44ayIwDeK4eGC16uMXXYPK
# 330  spotify:track:1PHJnbEqGrHuiNuWJWiqCc
# 331  spotify:track:19tvyPG8H7FqqBLePikeO4
# 332  spotify:track:6znJFrlww4NtoQFHDXNdwu
# 333  spotify:track:6jIf51que2Wcfoc2Ydc7Q2
# 334  spotify:track:1vlLZ0Sz4EyH8PxAEppGg0
# 335  spotify:track:2zcavp2fbc2jA8RxFNG5tq
# 336  spotify:track:3fF5NDC1ItEDJhDf7MZQ98
# 337  spotify:track:5RLGXFWKn60jaIM6yx1HQ5
# 338  spotify:track:5wLwV8xSTkPIgPfyiXEoNt
#
#                                             track_href  \
# 289  https://api.spotify.com/v1/tracks/3AGv2QUobr8H...
# 290  https://api.spotify.com/v1/tracks/4SPYSOCKjbNt...
# 291  https://api.spotify.com/v1/tracks/0564PAe6filH...
# 292  https://api.spotify.com/v1/tracks/0hRNITYJlzqX...
# 293  https://api.spotify.com/v1/tracks/4dmRDpT1AnD3...
# 294  https://api.spotify.com/v1/tracks/7Kp3GGTrXCHZ...
# 295  https://api.spotify.com/v1/tracks/4L4jSQSvsiyI...
# 296  https://api.spotify.com/v1/tracks/3n3YufvjOcWO...
# 297  https://api.spotify.com/v1/tracks/3IZAcDriHGLr...
# 298  https://api.spotify.com/v1/tracks/0gHCAqRH8ken...
# 299  https://api.spotify.com/v1/tracks/491hjuW7LQ1q...
# 300  https://api.spotify.com/v1/tracks/6U8vHWTaA6xS...
# 301  https://api.spotify.com/v1/tracks/2apzk8vtqGyO...
# 302  https://api.spotify.com/v1/tracks/67z26v7S4hua...
# 303  https://api.spotify.com/v1/tracks/0rRr78TVjpto...
# 304  https://api.spotify.com/v1/tracks/7vZlIVuCvDzw...
# 305  https://api.spotify.com/v1/tracks/1fltI0adkC78...
# 306  https://api.spotify.com/v1/tracks/5TUn5tl19ZMS...
# 307  https://api.spotify.com/v1/tracks/1v9IeqGO9HFQ...
# 308  https://api.spotify.com/v1/tracks/7ww5zeqxfiPA...
# 309  https://api.spotify.com/v1/tracks/6xHna5L0jPug...
# 310  https://api.spotify.com/v1/tracks/1DOp8uHcTRKo...
# 311  https://api.spotify.com/v1/tracks/38V22n3ftRos...
# 312  https://api.spotify.com/v1/tracks/1v8kKL2LTazv...
# 313  https://api.spotify.com/v1/tracks/76KFJR7JDtRH...
# 314  https://api.spotify.com/v1/tracks/65WPkLMModLG...
# 315  https://api.spotify.com/v1/tracks/5vgjzg0NBF4F...
# 316  https://api.spotify.com/v1/tracks/7InhiO5tWrC3...
# 317  https://api.spotify.com/v1/tracks/26fmRduARwMW...
# 318  https://api.spotify.com/v1/tracks/3h71urwqkBCb...
# 319  https://api.spotify.com/v1/tracks/2qbWok5i0LEL...
# 320  https://api.spotify.com/v1/tracks/0k2k4VBNf2jU...
# 321  https://api.spotify.com/v1/tracks/1ikgb3HRXxWX...
# 322  https://api.spotify.com/v1/tracks/3LW34iMfotuy...
# 323  https://api.spotify.com/v1/tracks/6y174doEFq6b...
# 324  https://api.spotify.com/v1/tracks/6KYOVZdNTFM4...
# 325  https://api.spotify.com/v1/tracks/60aWoqTtmKZd...
# 326  https://api.spotify.com/v1/tracks/308DhaYTyzrb...
# 327  https://api.spotify.com/v1/tracks/4dsJS2Q8tkPt...
# 328  https://api.spotify.com/v1/tracks/4LX54t9YXPri...
# 329  https://api.spotify.com/v1/tracks/44ayIwDeK4eG...
# 330  https://api.spotify.com/v1/tracks/1PHJnbEqGrHu...
# 331  https://api.spotify.com/v1/tracks/19tvyPG8H7Fq...
# 332  https://api.spotify.com/v1/tracks/6znJFrlww4Nt...
# 333  https://api.spotify.com/v1/tracks/6jIf51que2Wc...
# 334  https://api.spotify.com/v1/tracks/1vlLZ0Sz4EyH...
# 335  https://api.spotify.com/v1/tracks/2zcavp2fbc2j...
# 336  https://api.spotify.com/v1/tracks/3fF5NDC1ItED...
# 337  https://api.spotify.com/v1/tracks/5RLGXFWKn60j...
# 338  https://api.spotify.com/v1/tracks/5wLwV8xSTkPI...
#
#                                           analysis_url  duration_ms  \
# 289  https://api.spotify.com/v1/audio-analysis/3AGv...       224114
# 290  https://api.spotify.com/v1/audio-analysis/4SPY...       236250
# 291  https://api.spotify.com/v1/audio-analysis/0564...       351164
# 292  https://api.spotify.com/v1/audio-analysis/0hRN...       351164
# 293  https://api.spotify.com/v1/audio-analysis/4dmR...       197323
# 294  https://api.spotify.com/v1/audio-analysis/7Kp3...       264615
# 295  https://api.spotify.com/v1/audio-analysis/4L4j...       308320
# 296  https://api.spotify.com/v1/audio-analysis/3n3Y...       261410
# 297  https://api.spotify.com/v1/audio-analysis/3IZA...       234986
# 298  https://api.spotify.com/v1/audio-analysis/0gHC...       103554
# 299  https://api.spotify.com/v1/audio-analysis/491h...       236441
# 300  https://api.spotify.com/v1/audio-analysis/6U8v...       199889
# 301  https://api.spotify.com/v1/audio-analysis/2apz...       364253
# 302  https://api.spotify.com/v1/audio-analysis/67z2...       318627
# 303  https://api.spotify.com/v1/audio-analysis/0rRr...       240920
# 304  https://api.spotify.com/v1/audio-analysis/7vZl...       241213
# 305  https://api.spotify.com/v1/audio-analysis/1flt...       239360
# 306  https://api.spotify.com/v1/audio-analysis/5TUn...       281937
# 307  https://api.spotify.com/v1/audio-analysis/1v9I...       318810
# 308  https://api.spotify.com/v1/audio-analysis/7ww5...       288369
# 309  https://api.spotify.com/v1/audio-analysis/6xHn...       282828
# 310  https://api.spotify.com/v1/audio-analysis/1DOp...       309891
# 311  https://api.spotify.com/v1/audio-analysis/38V2...       280195
# 312  https://api.spotify.com/v1/audio-analysis/1v8k...       280241
# 313  https://api.spotify.com/v1/audio-analysis/76KF...       228720
# 314  https://api.spotify.com/v1/audio-analysis/65WP...       335480
# 315  https://api.spotify.com/v1/audio-analysis/5vgj...       265699
# 316  https://api.spotify.com/v1/audio-analysis/7Inh...       285283
# 317  https://api.spotify.com/v1/audio-analysis/26fm...       290613
# 318  https://api.spotify.com/v1/audio-analysis/3h71...       335228
# 319  https://api.spotify.com/v1/audio-analysis/2qbW...       292270
# 320  https://api.spotify.com/v1/audio-analysis/0k2k...       308363
# 321  https://api.spotify.com/v1/audio-analysis/1ikg...       350328
# 322  https://api.spotify.com/v1/audio-analysis/3LW3...       286413
# 323  https://api.spotify.com/v1/audio-analysis/6y17...       361093
# 324  https://api.spotify.com/v1/audio-analysis/6KYO...       300858
# 325  https://api.spotify.com/v1/audio-analysis/60aW...       277507
# 326  https://api.spotify.com/v1/audio-analysis/308D...       442187
# 327  https://api.spotify.com/v1/audio-analysis/4dsJ...       284467
# 328  https://api.spotify.com/v1/audio-analysis/4LX5...       285283
# 329  https://api.spotify.com/v1/audio-analysis/44ay...       287791
# 330  https://api.spotify.com/v1/audio-analysis/1PHJ...       261546
# 331  https://api.spotify.com/v1/audio-analysis/19tv...       308697
# 332  https://api.spotify.com/v1/audio-analysis/6znJ...       398898
# 333  https://api.spotify.com/v1/audio-analysis/6jIf...       300442
# 334  https://api.spotify.com/v1/audio-analysis/1vlL...       287039
# 335  https://api.spotify.com/v1/audio-analysis/2zca...       275973
# 336  https://api.spotify.com/v1/audio-analysis/3fF5...       338973
# 337  https://api.spotify.com/v1/audio-analysis/5RLG...       284238
# 338  https://api.spotify.com/v1/audio-analysis/5wLw...       453242
#
#      time_signature
# 289               4
# 290               4
# 291               3
# 292               3
# 293               4
# 294               4
# 295               4
# 296               4
# 297               4
# 298               4
# 299               4
# 300               4
# 301               4
# 302               4
# 303               4
# 304               4
# 305               4
# 306               4
# 307               4
# 308               3
# 309               4
# 310               4
# 311               3
# 312               3
# 313               4
# 314               4
# 315               4
# 316               4
# 317               4
# 318               3
# 319               4
# 320               3
# 321               4
# 322               3
# 323               4
# 324               4
# 325               4
# 326               1
# 327               4
# 328               3
# 329               3
# 330               4
# 331               4
# 332               4
# 333               4
# 334               4
# 335               4
# 336               4
# 337               4
# 338               3
